# %% [markdown]
# # Re-implementing Potash et al.’s GhostWriter: Using an LSTM for Automatic Rap Lyric Generation
#
#
# The purpose of this project is to compare four different models for ghost writing. Each model uses a different type of architecture to generate rap lyrics. The architectures consist of: SimpleRNN, GRU, LSTM, and CNN + LSTM <br>
#
# ## 1. Initial Setup
#
# For the data preparation and evaluation of the generated lyrics, we used the following Python libraries:
#
# - Pronouncing - Used for calculating rhyme index
# - Markovify - Used to create the base markov model for generating base lyrics
# - Textstat - Used to calculate the readability score for a bar
# - PyTorch-NLP - Used for tokenization

# %%
# !pip3 install pronouncing
# !pip3 install markovify
# !pip3 install textstat
# !pip3 install pytorch-nlp
# !pip3 install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: pronouncing in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: cmudict>=0.4.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pronouncing) (1.0.2)
# Requirement already satisfied: markovify in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (0.9.3)
# Requirement already satisfied: unidecode in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from markovify) (1.3.2)
# Requirement already satisfied: textstat in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (0.7.2)
# Requirement already satisfied: pyphen in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from textstat) (0.11.0)
# Requirement already satisfied: pytorch-nlp in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (0.5.0)
# Requirement already satisfied: tqdm in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pytorch-nlp) (4.59.0)
# Requirement already satisfied: numpy in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pytorch-nlp) (1.19.5)
# Requirement already satisfied: spacy in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.59.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: jinja2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: setuptools in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (58.5.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.7.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 8.8 MB/s
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.2.0) (3.2.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: jinja2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.25.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: setuptools in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.5.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.19.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.59.0)
# Requirement already satisfied: pathy>=0.3.5 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (20.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.4.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ganymede/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Data Preparation
#
# Load an artist's lyric file, remove the byte order mask, and split the file up into an array of bars.

# %%
from torch.utils.data import Dataset
import os 
import pandas as pd

#read dataset(s)
lyrics_data_Drake = open('./data/Drake_lyrics.txt', mode='r', encoding='utf8').read().split('\n')
lyrics_data_Childish = open('./data/Childish Gambino_lyrics.txt', mode='r', encoding='utf8').read().split('\n')
lyrics_data_Kanye = open('./data/Kanye West_lyrics.txt', mode='r', encoding='utf8').read().split('\n')

raw_data_Drake = {'Drake_data': [line for line in lyrics_data_Drake]}
#raw_data_Childish = {'Childish_data': [line for line in lyrics_data]}
#raw_data_Kanye = {'Kanye_data': [line for line in lyrics_data]}

#convert data to dataframe
df = pd.DataFrame(raw_data_Drake, columns = ['Drake_data'])

#shuffle dataset... is this necessary this early?
shuffle_dataframe = df.sample(frac=1)

#Split data : define size of training dataset
train_size = int(0.7*len(df))

#split into training and test set
train_set = shuffle_dataframe[:train_size]
test_set = shuffle_dataframe[train_size:]

#output for torchtext (needs a tabular dataset)
train_set.to_json('train.json', orient = 'records', lines =True)
test_set.to_json('test.json', orient = 'records', lines =True)

train_set.to_csv('train.csv', index=False)
test_set.to_csv('test.csv', index=False)

print(train_set), print(test_set)
# Out:
#                                              Drake_data
# 3044  Now it's, "Fuck you, I hate you, I'll move out...
# 3067                     And I finally send you to Rome
# 1927                                    Put a bib on me
# 3419  They was hatin' on me then and they hatin' now...
# 2223                                 Take a shot for me
# ...                                                 ...
# 1967                                Rock me real slowly
# 2018                                      I’m out here…
# 1830               I don't know who you're referring to
# 3969                         Steady doin' double shifts
# 3598               Niggas wouldn't make it on this side
#
# [2971 rows x 1 columns]
#                                              Drake_data
# 4028  This a "fuck-them-boys, forever-hold-a-grudge"...
# 4211  I bet them shits would have popped if I was wi...
# 2999                               They loving the crew
# 1811  For all the stuntin', I'll forever be immortal...
# 1243                                I'm too good to you
# ...                                                 ...
# 577                 Whole time they wanna take my place
# 2415         Griselda Blanco with the trap moves (trap)
# 2090
# 3684  So I'm with her even when I'm here without her...
# 2809                              Yeah, they know, yeah
#
# [1274 rows x 1 columns]
# (None, None)

# %% [markdown]
# ### Markov Model
#
# Create the Markov model that will be used for generating the initial first words for our lyric generator. The Markov model is used to ensure the first set of words for each bar has some coherence before feeding them into the neural network to generate the rest of the bar.

# %%
import markovify

#build Markov Model from training set
markov_model_Drake = markovify.NewlineText(str("\n".join(lyrics_data_Drake)), well_formed=False, state_size=3)
markov_model_Childish = markovify.NewlineText(lyrics_data_Childish)
markov_model_Kanye = markovify.NewlineText(lyrics_data_Kanye)

#generate random sentences of given length

sen_length = 4
print("Test Run Drake\n")
for i in range(sen_length):
    print(markov_model_Drake.make_sentence(tries=100))

#print("\n")
#print("Test Run Chidish Gambino\n")
#for i in range(sen_length):
#    print(markov_model_Childish.make_sentence(tries=100))

#print("\n")
#print("Test Run Kanye\n")
#for i in range(sen_length):
#    print(markov_model_Kanye.make_sentence(tries=100))
#print("\n")


#test dataset : generate "num_sentences" many random sentences of  "x_chars" length or less
x_chars = 50
num_sentences = 4

print("\n")
print("Drake\n")
for i in range(num_sentences):
    print(markov_model_Drake.make_short_sentence(x_chars))
print("\n")


#print("Childish Gambino\n")
#for i in range(num_sentences):
#    print(markov_model_Childish.make_short_sentence(x_chars))
#print("\n")

#print("Kanye\n")
#for i in range(num_sentences):
#    print(markov_model_Kanye.make_short_sentence(x_chars))
#print("\n")
# Out:
# Test Run Drake
#
# Own it, own it, own it, own it, own it, own it, own it, own it, own it, own it, own it
# I don't trust a word you say (I don't trust a word you say (I don't trust a word)
# And how I switched it up with a fork and knife for me
# 'Cause you're a good girl and you know how it goes
#
#
# Drake
#
# Make everybody have to go to funerals
# Pussy so good that you gotta be a thug for her
# I just pop up with the jokes, I'm dead, I'm asleep
# Yeah, and I could never do no wrong

# %% [markdown]
# ### Tokenization
#
# In order to create the training data, the lyrics need to be tokenized.
#
# Tokenizing allows for the bars to be represented as matricies that correspond to what words are used in a bar.

# %%
import torchtext
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f
from torch.utils.data import DataLoader
from torchtext.data.utils import get_tokenizer
from torchtext.data import Field, TabularDataset, BucketIterator
from torchnlp.encoders.text import StaticTokenizerEncoder, stack_and_pad_tensors, pad_tensor

# %%
#Tokenizer
tokenizer=get_tokenizer('spacy', language='en_core_web_sm')

#def tokenizer(input):
#   return [token.text for token in spacy_en.tokenizer(input)]

#convert data to dataframe
#raw_data_Drake = {'Drake_data': [line for line in lyrics_data_Drake]}
#df = pd.DataFrame(raw_data_Drake, columns = ['Drake_data', label])

TEXT = data.Field(tokenize=tokenizer, use_vocab=True, lower=True, batch_first=True, include_lengths=True)
#TEXT.build.vocab(train, max_size=25000, vectors="glove.6B.100d")
fields=[('text', TEXT)]

#sequences = lyrics_data_Drake
#encoder = StaticTokenizerEncoder(sequences, tokenize=lambda s: s.split())
#encoded_data = [encoder.encode(example) for example in sequences]

#print(encoded_data)
#print("\n")

#Create Dictionary
#fields = {'label':()}

#pad to get same size sequence (how do we know what size to pad?)
#feed seq to model


#create x and y data for training -- already have train set and test set
training_data = TabularDataset(
    path = 'train.csv', 
    format = 'csv',
    fields = fields,
    skip_header=True
)
for example in training_data.examples:
    print(example.text)

vectors=Vectors(name='glove.6B.100d.txt')
TEXT.build_vocab(training_data, vectors=vectors, max_size=10000, min_freq=1)
#train_X, train_y = seq[:, :-1], 

#train_x == full bar minus last word


#train_y == last word
# Out:
# ['now', 'it', "'s", ',', '"', 'fuck', 'you', ',', 'i', 'hate', 'you', ',', 'i', "'ll", 'move', 'out', 'in', 'a', 'heartbeat', '!', '"']
# ['and', 'i', 'finally', 'send', 'you', 'to', 'rome']
# ['put', 'a', 'bib', 'on', 'me']
# ['they', 'was', 'hatin', "'", 'on', 'me', 'then', 'and', 'they', 'hatin', "'", 'now', '(', 'hatin', "'", 'now', ')']
# ['take', 'a', 'shot', 'for', 'me']
# ['keep', 'a', 'broad', 'on', 'the', 'floor', 'year', "'", 'round', 'like', 'season', 'tickets']
# ['i', 'just', 'do', 'it', 'cause', 'i', "'m", "'", 'sposed', 'to', ',', 'nigga']
# ['wake', 'up', 'with', 'me', 'this', 'weekend', ',', 'we', 'can']
# ['niggas', 'is', 'frontin', "'", ',', 'that', "'s", 'upside', '-', 'down', 'cake']
# ['came', 'up', ',', 'that', "'s", 'all', 'me', ',', 'stay', 'true', ',', 'that', "'s", 'all', 'me']
# ['we', 'ai', 'n’t', 'even', 'have', 'a', 'tour', 'bus']
# ['got', 'a', 'lot', 'of', 'people', 'tryna', 'drain', 'me', 'of', 'this', 'energy']
# ['i', "'m", 'acting', 'out', 'in', 'the', 'open', ',', 'it', "'s", 'hard', 'for', 'you', 'to', 'ignore']
# ['whoa']
# ['people', 'i', 'believed', 'in', 'they', 'do', "n't", 'even', 'show', 'they', 'face', 'now']
# ['i', 'still', 'been', 'plottin', "'", 'on', 'the', 'low', ',', 'schemin', "'", 'on', 'the', 'low']
# ['free', 'smoke', ',', 'free', 'smoke', ',', 'ayy', '!']
# ['tat', 'on', 'my', 'ribs', 'like', 'i', 'do', 'not', 'know', 'what', 'permanent', 'is']
# ['a', 'pair', 'of', 'jordan', '3', "'s", 'tryna', 'chase', 'this', 'cash']
# ['all', 'my', 'people', 'been', 'here']
# ['we', 'make', 'a', 'mixtape', 'with', '17', 'songs']
# ['i', 'look', 'around', 'the', 'peers', 'that', 'surround', 'me', ',', 'these', 'niggas', 'tripping']
# ['that', 'kai', "'s", 'kitchen', 'in', 'a', 'canada', 'goose']
# ['i', 'do', "n't", 'pass', "'em", 'when', 'i', 'get', 'it', '(', 'naw', ')']
# ['smiling', 'back', 'when', 'they', 'pree', '(', 'jheeze', '!', ')']
# ['oh', 'ho', ',', 'i', 'know', 'it', ',', 'we', 'all', 'know', 'it']
# ['instead', ',', 'i', 'ask', 'myself', ',', '"', 'why', 'do', 'you', 'worry', '?', '"']
# []
# ['none', 'of', 'them', 'want', 'this', 'shit', 'more', 'than', 'i', 'want', 'it']
# ['trust', 'me', 'girl', ',', 'this', 'shit', 'is', 'everything', 'to', 'me']
# ['the', 'woman', 'that', 'i', 'would', 'try']
# ['i', 'guess', ',', 'for', 'the', 'fuck', '-', 'shit', 'i', "'m", 'biased']
# ['somewhere', 'between', 'i', 'want', 'it', 'and', 'i', 'got', 'it']
# ['skrrt', 'skrrt', ',', 'oh']
# ['fuck', 'any', 'nigga', 'that', "'s", 'talking', 'that', 'shit', 'just', 'to', 'get', 'a', 'reaction']
# ['you', 'got', 'ta', 'be', 'nice', 'for', 'what', 'to', 'these', 'niggas', '?']
# ['i', 'dedicate', ',', 'dedicate', ',', 'dedicate']
# ['no', 'help', ',', 'that', "'s", 'all', 'me', ',', 'all', 'me', 'for', 'real']
# ['you', 'have', "n't", 'been', 'the', 'man', 'for', 'like', 'a', 'minute']
# ['that', "'s", 'the', 'wrong', 'thing', 'to', 'do']
# ['that', "'s", 'the', 'wrong', 'thing', 'to', 'do']
# ['just', 'hold', 'on', ',', 'we', "'re", 'going', 'home', '(', 'going', 'home', ')']
# ['you', 'runnin', "'", 'your', 'fingers', 'through', 'my', 'curls']
# ['i', 'might', 'get', 'a', 'key', 'to', 'the', 'city', 'and', 'give', 'it', 'to', 'wayne']
# ['i', 'took', 'a', 'break', 'from', 'views', ',', 'now', 'it', "'s", 'back', 'to', 'that', ',', 'nigga', '(', 'six', ')']
# ['wine', 'it', ',', 'wine', 'it', ',', 'very', 'long', 'time']
# ['care', 'for', 'me', ',', 'care', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'care', 'for', 'me']
# ['bunch', 'of', 'journalists', 'been', 'searchin', "'", 'for', 'a', 'story']
# ['fucka', 'never', 'loved', 'us']
# ['do', "n't", 'be', 'ashamed', ',', 'it', "'s", 'plenty', 'niggas', 'that', 'do', 'what', 'you', 'do']
# ['there', "'s", 'times', 'when', 'i', 'might', 'blow', 'like', '50k', 'on', 'a', 'vacation']
# ['that', "'s", 'been', 'where', 'you', 'find', 'me', 'at']
# ['might', 'go', 'down', 'a', 'g.o.d.', ',', 'yeah', ',', 'wait']
# ['skrrt', 'skrrt', ',', 'oh']
# ['if', 'you', 'ai', 'n’t', 'running', 'games']
# ['no', 'help', ',', 'that', "'s", 'all', 'me', ',', 'all', 'me', 'for', 'real']
# ['i', "'ve", 'stopped', 'listening', 'to', 'things', 'you', 'say']
# []
# ['cause', 'you', 'do', "n't", 'say', 'you', 'love', 'me', 'to', 'your', 'friends', 'when', 'they', 'ask', 'you']
# ['and', 'i', "'ll", 'start', 'hatin', "'", 'only', 'if', 'you', 'make', 'me']
# ['i', "'m", 'not', 'even', 'christian', ',', 'i', 'still', 'went', 'to', 'church', 'that', 'year']
# ['i', 'give', 'a', 'fuck', 'about', 'your', 'mob', ',', 'boy', '(', 'oh', ')']
# ['i', 'got', 'strippers', 'in', 'my', 'life', ',', 'but', 'they', 'virgins', 'to', 'me']
# ['every', 'time', 'i', 'see', '‘', 'em', ',', 'somethin’', 'wrong', 'with', 'their', 'memory']
# ['they', 'ca', "n't", 'live', 'this', 'long']
# ['like', 'controlla', ',', 'controlla', ',', 'yeah']
# ['been', 'ready', ',', 'it', "'s", 'real', ',', 'i', 'do', "n't", 'know', "'bout", 'you']
# ['hermès', 'link', ',', 'ice', '-', 'blue', 'mink']
# ['we', 'the', 'one', 'droppin', "'", 'niggas', ',', 'we', 'the', 'ones', '(', 'we', 'the', 'ones', ')']
# ["y'all", 'keep', 'talking', '‘', 'bout', 'who', 'next', ',', 'but', 'i', '’m', 'about', 'as', 'big', 'as', 'it', 'gets']
# ['tat', 'on', 'my', 'ribs', 'like', 'i', 'do', 'not', 'know', 'what', 'permanent', 'is']
# ['do', "n't", 'make', 'me', 'break', 'your', 'kevin', 'hart', ',', 'boy']
# ['then', 'you', 'find', 'it', ',', 'awkward', 'silence']
# []
# ['this', 'a', '"', 'doing', '-', 'me', '-', 'and', '-', 'only', '-', 'god', '-', 'can', '-', 'judge', '"', 'song']
# ['hate', 'when', 'they', 'get', 'too', 'attached', 'to', 'me']
# ['stop', ',', 'stop', ',', 'stop', '...']
# ['i', 'do', "n't", 'wanna', 'hear', 'about', 'this', 'ever', 'again']
# ['ever', 'since', 'i', 'left', 'the', 'city', ',', 'you']
# ['if', 'i', 'die', ',', 'i', "'m", 'a', 'legend']
# ['give', 'to', 'me', ',', 'give', 'to', 'me', ',', 'why', 'wo', "n't", 'you', 'live', 'for', 'me', '?']
# ['cause', 'you', 'do', "n't", 'really', 'wanna', 'hear', 'me', 'vent', 'more']
# ['maybe', 'i', "'m", 'searchin', "'", 'for', 'the', 'problems']
# ['just', 'to', 'tell', 'me', 'they', 'ai', 'n’t', 'really', 'friends']
# ['ten', 'million', 'dollars', ',', 'got', 'ta', 'hide', 'the', 'safe']
# ['mothafuckas', 'never', 'loved', 'us']
# []
# ['22', '.', 'do', 'not', 'disturb']
# ['it', 'do', "n't", 'work', 'like', 'that', 'when', 'you', 'love', 'somebody']
# ["'cause", 'if', 'we', 'judging', 'off', 'your', 'advances']
# ['now', 'she', 'want', 'a', 'photo', ',', 'you', 'already', 'know', ',', 'though']
# ['yeah', ',', 'and', 'fuck', ',', 'you', 'left', 'the', 'boy', 'no', 'options']
# ['cause', 'we', 'never', 'decided']
# ['take', 'a', 'shot', 'for', 'me']
# ['sold', 'a', 'couple', 'bentley', 'last', 'week']
# ['my', 'life', "'s", 'a', 'completed', 'checklist']
# ['i', 'should', 'call', 'one', 'and', 'go', 'home']
# []
# ['when', 'you', "'re", 'stressed', 'out', 'and', 'you', 'need', 'something', ',', 'i', 'got', 'you']
# ['and', 'i', 'do', "n't", 'feel', 'that', 'shit', ',', 'not', 'even', 'a', 'little', 'bit']
# ['like', 'controlla', ',', 'controlla', ',', 'yeah']
# ['guess', 'whose', 'it', 'is', '?', 'guess', 'whose', 'it', 'is', '?', 'yours']
# ['they', 'love', 'your', 'son', '—', 'man', ',', 'that', 'boy', 'gone']
# ['you', 'knew', 'that', 'i', 'was', 'gon', 'na', 'be', 'something']
# ['you', 'used', 'to', ',', 'you', 'used', 'to']
# []
# ['go', 'own', 'that', 'shit', ',', 'it', "'s", 'yours', ',', 'it', "'s", 'yours', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it']
# ['why', 'has', 'it', 'been', '?', 'why', 'has', 'it', 'been', '?']
# ['just', 'me', 'and', 'my', 'old', 'man', 'getting', 'back', 'to', 'basics']
# ["nothin'", 'really', 'changed', 'but', 'still', 'they', 'look', 'at', 'me', 'a', 'way', 'now']
# ['say', 'my', 'name']
# ['and', 'drizzy', 'got', 'the', 'money', ',', 'so', 'drizzy', 'gon', 'na', 'pay', 'it']
# ['it', "'s", 'yours']
# ['to', 'see', 'who', 'really', 'with', 'you']
# ['if', 'we', 'do', 'a', 'song', 'it', "'s", 'like', 'takin', "'", 'my', 'kids', 'to', 'work', 'with', 'me']
# ['last', 'verse', 'that', 'i', 'got', 'ta', 'do', 'is', 'always', 'like', 'surgery']
# ['you', 'only', 'live', 'once', ':', 'that', "'s", 'the', 'motto', ',', 'nigga', ',', 'yolo']
# ['you', 'gon', "'", 'make', 'someone', 'around', 'me', 'catch', 'a', 'body', 'like', 'that']
# ['5', '.', 'get', 'it', 'together', 'ft', '.', 'black', 'coffee', 'and', 'jorja', 'smith']
# ['there', "'s", 'never', 'much', 'love', 'when', 'we', 'go', 'ot']
# ['they', 'loving', 'the', 'crew']
# ["doin'", 'overtime', 'for', 'the', 'last', 'month']
# []
# ['they', 'wishin', "'", 'on', 'me', ',', 'yeah', ',', 'yeah']
# ['give', 'to', 'me', ',', 'give', 'to', 'me', ',', 'why', 'wo', "n't", 'you', 'live', 'for', 'me', '?']
# ['i', 'take', 'a', 'glass', 'of', 'domina', 'to', 'go', 'with', 'me', 'home']
# ['luckily', 'i', 'did', "n't", 'have', 'to', 'grow', 'there']
# ['i', "'ll", 'admit', 'it', ',', 'i', "'ve", 'admitted', 'to', 'a', 'lot', 'of', 'things']
# ['they', 'wishin', "'", 'on', 'me', ',', 'yuh']
# ['i', 'still', 'got', 'ten', 'years', 'to', 'go', ',', 'huh', '?']
# ['and', 'taint', 'all', 'the', 'images', 'of', 'your', '"', 'mr.', 'perfect', '"']
# ['right', 'before', 'wayne', 'came', 'and', 'got', 'me']
# ['whole', 'squad', 'on', 'that', 'real', 'shit']
# ['back', 'to', 'back', ',', 'like', 'i', "'m", 'on', 'the', 'cover', 'of', 'lethal', 'weapon']
# ['fuckin', "'", 'right', ',', 'fuckin', "'", 'right', ',', 'alright']
# ['fuck', 'all', 'that', 'rap', '-', 'to', '-', 'pay', '-', 'your', '-', 'bill', 'shit']
# []
# ['oh', ',', 'where', 'i', 'reside', 'it', 'look', 'like', 'a', 'resort', 'inside']
# ['stadium', 'packed', ',', 'just', 'glad', 'to', 'see', 'the', 'city', 'on', 'the', 'map']
# ['"', 'pop', '-', 'some', '-', 'fucking', '-', 'champagne', '-', 'in', '-', 'the', '-', 'tub', '"', 'song']
# ['oh', ',', 'i', 'know', ',', 'i', 'know', 'you', 'do', "n't", 'love', 'me', ',', 'baby']
# ['hi', 'aubrey', ',', 'i', "'m", 'here', 'sitting', 'with', 'my', 'son', 'having', 'a', 'little', 'talk', '—', 'and', 'he', 'knows', 'how', 'to', 'get', 'in', 'touch', 'with', 'you', 'now', ',', 'to', 'let', 'you', 'know', 'how', 'grateful', 'i', 'am', 'for', 'your', 'help', 'in', 'keeping', 'me', 'in', 'this', '—', 'in', 'this', 'comfortable', 'place', '.', 'all', 'i', 'can', 'say', ',', 'aubrey', ',', 'is', 'i', 'remember', 'the', 'good', 'times', 'we', 'had', 'together', ',', 'and', 'the', 'times', 'i', 'used', 'to', 'look', 'after', 'you', '.', 'and', 'i', 'still', 'have', 'wonderful', 'feelings', 'about', 'that', '.', 'so', 'god', 'bless', 'you', ',', 'and', 'i', 'hope', 'i', "'ll", 'see', 'you', '...']
# ['girl', ',', 'you', 'got', 'that', 'thing', 'for', 'real']
# ['cause', 'you', 'deserve', 'it']
# ['told', 'me', 'everything', 'about', 'you']
# ['to', 'heat', 'up', 'the', 'city', ',', 'and', 'that', "'s", 'word', 'to', 'stunna', ',', 'you', 'know', 'it']
# []
# ['i', "'m", 'just', 'as', 'famous', 'as', 'my', 'mentor']
# ['i', 'be', 'dressed', 'before', 'we', 'hung', 'up']
# ['all', 'you', 'boys', 'in', 'the', 'new', 'toronto', 'want', 'to', 'be', 'me', 'a', 'little']
# ['i', "'m", 'in', 'the', 'building', 'and', 'i', "'m", 'feeling', 'myself']
# ['you', 'be', 'like', '"', 'oh', ',', 'word', ',', 'true', 'shit', '?', '"']
# ['well', 'if', 'it', "'s", 'all', 'a', 'dream']
# ['i', "'m", 'way', 'up', ',', 'i', 'stay', 'up', ',', 'i', "'m", 'two', 'up', ',', 'i', "'m", 'three', 'up']
# ['i', 'saw', 'my', 'parents', 'split', 'up', 'right', 'after', 'the', 'wedding']
# ['i', 'ca', "n't", 'do', 'this', 'on', 'my', 'own', ',', 'ayy', ',', 'no', ',', 'ayy']
# ['only', 'over', 'my', 'dead', 'body']
# ['man', ',', 'i', "'m", 'talkin', "'", 'way', 'before', 'hashtags']
# ['i', 'made', '!', '(', 'watch', 'the', 'breakdown', ')']
# ['wonder', 'if', 'you', "'re", 'bendin', "'", 'over', 'backwards', 'for', 'someone', 'else']
# []
# ['then', 'that', 'phone', 'does', "n't", 'ring']
# ['get', 'lil', "'", 'updates', ',', 'texts', 'in', 'my', 'inboxes', 'have', 'been', 'poppin', "'"]
# ['look', 'what', 'you', "'ve", 'done', ',', 'look', 'what', 'you', "'ve", 'done']
# []
# ['and', 'nowadays', 'when', 'i', 'ask', 'about', 'who', 'got', 'it', ',', 'they', 'say', 'it', "'s", 'yours']
# ['people', 'are', 'funny', ',', 'you', 'do', "n't", 'even', 'know']
# ['i', "'m", 'just', 'tryna', 'connect', 'with', "somethin'", 'baby']
# ['nigga', ',', 'i', "'m", 'just', 'flexin', "'"]
# ['i', 'told', 'you', 'keep', 'playin', "'", 'with', 'my', 'name']
# ['nobody', 'else', "'s", ',', 'yeah', ',', 'this', 'shit', 'belong', 'to', 'nobody', 'and', 'that']
# ['that', 'i', "'m", 'a', 'call', 'her', 'anyway', ',', 'and', 'say', '…']
# ['everywhere', 'we', 'go', ',', 'we', 'leave', 'a', 'worldwide', 'mess']
# ['late', 'night', 'when', 'you', 'need', 'my', 'love']
# ['i', 'said', '"', 'girl', ',', 'that', "'s", 'all', 'that', 'we', 'do', '.', '"']
# ['it', "'s", 'a', 'lot', 'of', 'bad', 'things']
# ['i', "'m", 'not', 'new', 'to', 'this']
# ['wish', 'a', 'nigga', 'would', ',', 'like', 'a', 'tree', 'in', 'this', 'bitch']
# ['i', "'m", 'just', 'like', 'a', 'baby', ',', 'droolin', "'", 'over', 'you']
# ['it', 'seem', 'like', 'you', 'do', "n't", 'want', 'this', 'love', 'anymore']
# ['oh', '-', 'oh', ',', 'i', 'guess', 'that', "'s", 'just', 'the', 'motion']
# ['shit', 'hot', 'up', 'in', 'the', '6', ',', 'boy', '(', 'hot', 'up', 'in', 'the', '6', ')']
# ['no', 'dinners', ',', 'no', 'holidays', ',', 'no', "nothin'"]
# ['come', 'see', 'us', 'and', 'get', 'it', 'fixed', ',', 'boy', '(', 'hey', ')']
# ['been', 'ready', ',', 'it', "'s", 'real', ',', 'i', 'do', "n't", 'know', "'bout", 'you']
# ['distractions', 'will', 'do', 'you', 'in', ',', 'in', 'the', 'truest', 'sense']
# ['lately', 'you', 'just', 'make', 'me', 'work', 'too', 'hard', 'for', 'you']
# ['bend', 'it', 'over', ',', 'lift', 'it', 'up', ',', 'bend', 'it', 'over', ',', 'lift', 'it', 'up']
# ['i', 'thank', 'god', 'you', 'came']
# ['and', 'do', "n't", 'assume', 'cause', 'i', 'do', "n't", 'respect', 'assumptions', 'bae']
# ['(', 'louisiana', 'shit', ')']
# ['watch', 'the', 'breakdown']
# ['own', 'it', ',', 'baby', ',', 'own', 'it', ',', 'it', "'s", 'yours', ',', 'own', 'that', 'shit', ',', 'own', 'that', 'shit', ',', 'own', 'that', 'shit']
# ['leavin', "'"]
# ['tell', 'me', 'how', 'you', 'feel', 'inside']
# ['get', 'the', 'fuck', 'up', 'out', 'my', 'dressing', 'room', ',', 'confusing', 'me', 'with', 'questions', 'like']
# ['my', 'momma', 'told', 'me', 'this', 'was', 'right', 'for', 'me']
# ['now', 'they', 'like', ',', '"', 'are', "n't", 'you', 'adorable', '?', '"']
# ['how', 'much', 'time', 'is', 'this', 'nigga', 'spendin', "'", 'on', 'the', 'intro', '?']
# ["'", 'fore', 'the', 'end', 'of', 'this', 'year']
# ['nope', ',', 'no', 'way', ',', 'nah']
# ['i', 'see', 'all', 'of', 'her', 'friends', 'here']
# ['like', 'it', "'s", 'legalized']
# []
# ['on', 'my', 'way', ',', 'money', 'taught', 'me', 'spanish', ',', 'make', 'it', 'andale']
# ['i', 'think', 'i', "'d", 'lie', 'for', 'you']
# ['tryna', 'get', 'my', 'karma', 'up', ',', 'fuck', 'the', 'guilty', 'and', 'greedy', 'shit']
# ['i', 'need', 'someone', 'different']
# ['12', '.', 'sacrifices', 'ft', '.', '2', 'chainz', 'and', 'young', 'thug']
# ['i', "'m", 'the', 'one', ',', 'one']
# ['and', 'now', 'you', "'re", 'tryna', 'make', 'me', 'feel', 'a', 'way', ',', 'on', 'purpose']
# ['whole', 'time', 'they', 'wanna', 'take', 'my', 'place']
# ['if', 'you', 'hurt', ',', 'i', 'do', "n't", 'tell', 'you']
# ['i', '’m', 'getting', 'paid', 'for', 'all', 'of', 'this', 'shit']
# []
# ['shout', 'out', 'to', 'world', 'wide', 'wes']
# ['yeah']
# []
# ['saturday', ',', 'call', 'the', 'girls', ',', 'get', "'em", 'gassed', 'up']
# ['rode', 'that', 'dick', 'like', 'a', 'soldier']
# ['almost', 'gave', 'up', 'on', 'the', 'music', 'thing']
# ['i', "'m", 'never', 'washed', ',', 'but', 'i', "'m", 'not', 'new']
# ['and', 'i', 'sit', 'next', 'to', 'you', 'and', 'i', 'lecture', 'you']
# ['i', 'been', 'at', 'the', 'house', 'taking', 'no', 'calls']
# ['rumor', 'has', 'it', ',', 'i', 'steer', 'the', 'ship', 'with', 'my', 'eyes', 'closed']
# ['long', 'as', 'the', 'outcome', 'is', 'income']
# []
# ['those', 'are', 'strings', 'that', 'you', 'ca', 'n’t', 'pull']
# ['tell', 'me', ',', 'have', 'you', 'heard', 'that', 'lately', '?']
# ['i', 'stay', 'silent', '‘', 'cause', 'we', 'at', 'war', 'and', 'i', '’m', 'very', 'patient']
# ['started', 'from', 'the', 'bottom', ',', 'now', 'my', 'whole', 'team', 'here', ',', 'nigga']
# ['i', 'bought', 'my', 'niggas', 'rollies', 'off', 'of', 'thank', 'me', 'later']
# ['yeah', ',', 'bounce', 'that', 'shit', 'like', 'woah']
# ['whenever', 'they', 'say', "somethin'", 'bout', 'us', 'you', 'listen']
# ['i', "'ve", 'been', 'dealing', 'with', 'my', 'dad', ',', 'speaking', 'of', 'lack', 'of', 'patience']
# ['woah', ',', 'woah', ',', 'heard', 'all', 'of', 'the', 'stories', 'about', 'you']
# ['say', 'my', 'name']
# []
# ['i', 'think', 'there', "'s", 'something', ',', 'baby']
# ['so', 'i', 'can', 'say', 'it', 'to', 'your', 'face']
# ['and', 'they', 'do', "n't", 'have', 'no', 'award', 'for', 'that']
# ['i', "'m", 'like', ',', '"', 'why', 'i', 'got', 'ta', 'be', 'all', 'that', '?', '"']
# ['that', "'s", 'the', 'reason', 'you', 'can', 'feel', 'the', 'tension', 'and', 'the', 'urgency']
# ['i', 'been', 'taught', 'to', 'never', 'loan', 'somebody']
# ['just', 'throw', 'up', 'while', 'i', 'hold', 'your', 'hair', 'back']
# ['them', 'were', 'my', 'old', 'toys', '(', 'man', 'this', 'shit', 'is', 'old', ')']
# ['ever', 'since', 'i', 'left', 'the', 'city', '…']
# ['always', 'haffi', 'look', 'out', ',', 'yuh', 'no', 'know', 'if', 'yuh', 'head', 'book', 'out']
# ['i', 'drove', 'here', 'in', 'the', 'wraith', 'playin', "'", 'ar', '-', 'ab']
# ['nigga', ',', 'i', 'could', 'turn', 'your', 'boy', 'into', 'the', 'man']
# ['i', "'ve", 'been', 'peepin', "'", 'what', 'you', 'bringin', "'", 'to', 'the', 'table']
# ['bitch', ',', 'i', 'know', 'you', 'heard', 'things']
# ['nah', ',', 'fuck', 'all', 'of', 'you', 'niggas', ',', 'i', 'ai', 'n’t', 'finished']
# ['and', 'i', 'blame', 'where', 'i', 'came', 'from']
# ['so', 'watch', 'how', 'you', 'speak', 'on', 'my', 'name', ',', 'you', 'know', '?']
# ['conversation', 'was', "n't", 'that', 'long']
# ['let', 'me', 'get', 'your', 'ass', 'alone']
# ['yeah', ',', 'yeah', ',', 'yeah']
# ['(', 'oohh', ',', 'do', "n't", 'think', 'about', '..', ')']
# ['after', 'all', 'the', 'things', 'that', 'we', 'been', 'through', ',', 'i', 'got', 'you']
# ['album', 'art', ':']
# ['c.r.e.a.m.', 'get', 'the', 'money', ',', 'dolla', '-', 'dolla', 'bill', "y'", 'all']
# ['i', 'love', 'me', ',', 'i', 'love', 'me', 'enough', 'for', 'the', 'both', 'of', 'us']
# ["beans'a", 'tell', 'you', 'if', 'he', 'was', "n't", 'in', 'his', 'feelins']
# ['a', 'nigga', 'fillin', "'", 'up', 'arenas', ',', 'who', 'the', 'fuck', 'could', 'see', 'us', '?']
# ['but', 'if', 'the', 'devil', "'s", 'in', 'the', 'details', ',', 'then', 'i', "'m", 'satanic']
# ['the', 'other', 'night']
# ['i', 'give', 'chanel', 'out', 'like', 'a', 'hug', ',', 'i', 'know']
# ['off', 'everything', 'my', 'pen', 'wrote', 'we', 'went', 'from', 'bundy', 'to', 'winslow']
# ['cause', 'if', 'i', "'m", 'going', 'anywhere', ',', 'it', "'s", 'probably', 'too', 'far']
# ['like', 'controlla', ',', 'controlla', ',', 'yeah']
# ['you', 'overnight', 'celebrity', ',', 'you', 'one', 'day', 'star']
# ['i', 'ca', "n't", 'get', 'over', 'you']
# ['you', 'know', 'it', ',', 'oh', 'ho', ',', 'she', 'knows', 'it']
# ["'cause", 'she', 'supported', 'since', 'hot', 'beats']
# ['my', 'time', 'with', 'you', ',', 'my']
# ['i', "'m", 'not', 'scared', 'of', 'it', ',', 'she', 'ai', "n't", 'either']
# ['they', 'loving', 'the', 'crew']
# []
# []
# ['you', 'can', 'have', 'her', 'when', 'i', "'m", 'finished', '(', 'why', '?', ')']
# ['my', 'last', 'girl', 'would', 'tear', 'me', 'apart']
# ['rock', 'me', 'real', 'slowly']
# ['got', 'ta', ',', 'g', '-', 'g', '-', 'gotta', ',', 'got', 'ta', ',', 'got', 'ta', 'make', 'that', 'jump', ',', 'jump', '(', 'let', "'s", 'go', ')']
# ['i', 'get', 'paid', 'a', 'lot', ',', 'you', 'get', 'paid', 'a', 'bit']
# ['only', 'over', 'my', 'dead', 'body']
# ['but', 'my', 'mind', 'did', "n't", 'change', 'and', 'i', 'still', 'feel', 'the', 'same']
# ['but', 'i', 'need', 'someone', 'different']
# ['now', 'she', 'want', 'a', 'photo', ',', 'you', 'already', 'know', ',', 'though']
# ['sprite', 'in', 'that', 'mixture']
# ['shit', 'do', "n't", 'come', 'with', 'trophies', ',', 'ai', "n't", 'no', 'envelopes', 'to', 'open']
# ['it', "'s", 'a', 'short', 'life', ',', 'yeah']
# ['then', 'we', 'got', 'to', 'talking', "'bout", 'something', 'we', 'disagreed', 'on']
# ['no', ',', 'you', 'ca', "n't", '"', 'son', '"', 'me']
# ['it', "'s", 'too', 'late', 'for', 'my', 'city', ',', 'i', "'m", 'the', 'youngest', 'nigga', 'reppin', "'"]
# ['any', 'more', 'henny', 'and', 'you', "'re", 'past', 'the', 'limit']
# []
# ['fuckin', '’', 'with', 'the', 'kid', 'and', 'pray', 'for', 'your', 'nigga']
# ['every', 'time', 'you', 'see', 'a', 'nigga', '–', 'stunt', ',', 'nigga', '!']
# ['especially', 'people', 'that', 'want', 'to', 'lecture', 'me']
# ['figured', 'out', 'this', 'shit', 'is', 'simple']
# ['i', 'got', 'people', 'talkin', '’', 'down', ',', 'man', ',', 'like', 'i', 'give', 'a', 'fuck']
# ['girl', ',', 'you', 'got', 'me', 'down', ',', 'you', 'got', 'me', 'stressed', 'out']
# ['that', 'the', 'real', 'is', 'on', 'the', 'rise']
# ['and', 'they', 'never', 'will']
# ['you', 'take', 'my', 'love', 'for', 'granted']
# ['type', 'of', 'money', ',', 'everybody', 'acting', 'like', 'they', 'knew', 'ya']
# ['i', 'got', '40', 'in', 'the', 'studio', ',', 'every', 'night', ',', 'late', 'night']
# ['and', 'i', 'wish', 'she', 'was', "n't", 'married']
# ['those', 'my', 'brothers', ',', 'i', 'ai', "n't", 'even', 'got', 'ta', 'say', 'it']
# []
# ['thought', 'of', 'things', 'that', 'you', 'shoulda', 'said', ',', 'said', 'things', 'that', 'you', 'should', 'n’t', 'say']
# ['remember', '?', 'mothafucka', 'never', 'loved', 'us']
# ['they', 'be', 'on', 'that', 'rap', '-', 'to', '-', 'pay', '-', 'the', '-', 'bill', 'shit']
# ['i', 'see', 'painkillers', 'on', 'the', 'kitchen', 'counter']
# ['talked', 'to', 'me', ',', 'you', 'got', 'to', 'me']
# ['fuckin', "'", 'right', ',', 'damn', "'", 'right', ',', 'alright', ',', 'yeah', ')']
# ['‘', 'cause', 'one', 'of', 'us', 'goes', 'in', ',', 'and', 'we', 'all', 'go', 'through', 'it']
# ['i', 'wanna', 'move', 'to', 'dubai']
# ['so', 'i', 'do', "n't", 'know', 'what', "'s", 'wrong', 'with', 'these']
# ['i', 'said', '"', 'girl', ',', 'that', "'s", 'all', 'that', 'we', 'do', '.', '"']
# ['could', 'it', 'be', 'the', 'way', 'that', 'i', "'ll", 'catch', 'up']
# ['that', "'s", 'got', 'all', 'you', 'niggas', 'excited']
# ['she', 'call', 'and', 'tell', 'me', 'be', 'here', 'before', 'the', 'sun', 'up']
# ['she', 'just', 'want', 'to', 'smoke', 'and', 'fuck']
# ['i', 'touched', 'down', 'in', "'", '86', ',', 'knew', 'i', 'was', 'the', 'man', 'by', 'the', 'age', 'of', '6']
# ['listen']
# ['i', "'m", 'not', 'sure', 'what', 'it', 'was', 'that', 'really', 'made', "y'", 'all', 'mad']
# ['with', 'the', 'ink', 'i', 'could', 'murder', ',', 'word', 'to', 'my', 'nigga', 'irv']
# ['schemin', "'", ',', 'plottin', "'", ',', 'schemin', "'", ',', 'gettin', "'", 'money']
# ['i', 'guess', 'that', "'s", 'just', 'the', 'motion']
# ['that', 'can', 'only', 'mean', 'one', 'thing']
# ['i', 'put', 'my', 'hands', 'around', 'you']
# ['he', 'said', 'we', 'should', 'hash', 'it', 'out', 'like', 'a', 'couple', 'of', 'grown', 'ups']
# ['i', 'was', 'aggressive', 'and', 'she', 'was', 'sober']
# ['girl', ',', 'i', 'had', 'your', 'back', 'when', 'all', 'you', 'used', 'to', 'do', 'was', 'front']
# ['pack', 'a', 'bag', ',', 'you', 'gon', "'", 'end', 'up', 'staying', 'where', 'i', "'m", 'at']
# []
# ['oh', ',', 'you', 'thought', 'you', 'had', 'it', 'all', 'figured', 'out', 'back', 'then']
# ['you', 'left', 'your', 'mark', 'on', 'me']
# []
# ['i', 'bought', 'your', 'dad', 'a', 'bunch', 'of', 'shit', 'for', 'christmas']
# ['17', '.', 'ca', "n't", 'have', 'everything']
# ['got', 'a', 'hennessy', 'in', 'my', 'hand']
# ['between', 'us', 'just', 'like', 'picket', 'fences']
# ['she', 'rode', 'that', 'dick', 'like', 'a', 'soldier']
# ['you', 'and', 'me', ',', 'we', 'just', 'do', "n't", 'get', 'along']
# ['i', 'give', 'you', 'my', 'fortune']
# ['niggas', 'downplayin', "'", 'the', 'money']
# ['chris', 'breezy', 'with', 'the', 'dance', 'moves']
# ['own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'i', 'said']
# ['i', "'m", 'turnin', "'", 'into', 'a', 'nigga', 'that', 'thinks', 'about', 'money', 'and', 'women']
# ['and', 'that', "'s", 'some', 'real', 'shit']
# ['you', 'know', 'how', 'that', 'should', 'go']
# ['i', 'learned', 'working', 'with', 'the', 'negatives']
# ['japanese', 'for', 'the', 'yen', 'that', 'i', "'m", 'handlin', "'"]
# ['bitch', 'i', 'go', 'to', 'dreams', 'with', 'a', 'suitcase']
# ['what', 'about', 'now', ',', 'girl', ',', 'how', "'bout", 'now', '?']
# []
# ['how', 'many', 'girls', 'have', 'slept', 'in', 'this', 'bed', '?']
# ['make', 'me', 'call', 'my', 'bros', 'for', 'assistance']
# ['and', 'still', 'got', 'ta', 'pull', 'out']
# ['they', 'already', 'had', 'a', 'stage', 'and', 'a', 'booty', 'pole']
# ['gets', 'me', 'a', 'flight', 'to', 'houston', 'in', 'the', 'morning']
# ['you', 'send', 'the', '"', 'are', 'you', 'here', '?', '"', 'text', 'without', 'an', 'invite']
# ['15', '.', 'kmt', 'ft', '.', 'giggs']
# ['and', 'we', 'bout', 'it', 'every', 'day', ',', 'every', 'day', ',', 'every', 'day']
# ['i', "'m", 'way', 'too', 'good', 'to', 'you']
# ['look', 'like', 'you', 'hidin', "'", 'your', 'problems']
# ['and', 'this', 'ai', 'n’t', 'no', 'time', 'for', 'locking', 'your', 'phone', 'and', 'not', 'coming', 'home']
# ['but', 'fuck', 'what', 'they', 'talkin', "'", 'about', 'on', 'your', 'timeline']
# ['could', 'it', 'be', 'the', 'way', 'that', 'i', "'ll", 'catch', 'up']
# []
# ['where', 'have', 'you', 'been', '?']
# ['that', "'s", 'just', 'me', 'on', 'my', 'solo', 'like', 'fuck', 'it', ',', 'like', 'yolo']
# ['dedicate', 'to', 'you']
# ['no', 'new', 'niggas', ',', 'nigga', ',', 'we', 'do', "n't", 'feel', 'that']
# ['omg', ',', 'niggas', 'sleep', ',', 'i', 'ai', "n't", 'trippin', "'", ',', 'i', "'m", 'a', 'let', "'em", 'sleep']
# []
# ['and', 'then', 'i', 'just', 'get', 'on', 'the', 'jet', 'and', 'go', 'back', 'to', 'the', 'cold']
# ['you', 'better', 'off', 'not', 'saying', 'nothing']
# ['nah', ',', 'niggas', 'ai', "n't", 'about', 'to', 'starve', 'us']
# ['and', 'there', "'s", 'things', 'you', 'got', 'ta', 'go', 'through']
# ['that', 'they', 'wishin', "'", 'and', 'wishin', "'", 'and', 'wishin', "'", 'and', 'wishin', "'"]
# ['yeah', ',', 'yeah', ',', 'fam']
# ['done', 'sayin', "'", 'i', "'m", 'done', 'playin', "'"]
# ['yeah', ',', 'i', 'could', "n't", 'get', 'a', 'bill', 'paid']
# ['i', 'come', 'through', 'in', 'whips', 'that', 'make', 'a', 'young', 'boy', 'take', 'the', 'long', 'way', 'home']
# ['omg', ',', 'niggas', 'sleep', ',', 'i', 'ai', "n't", 'trippin', "'", ',', 'i', "'m", 'a', 'let', "'em", 'sleep']
# ['but', 'every', 'time', 'we', 'speakin', "'"]
# ['(', 'do', "n't", 'do', 'that', '..', ')']
# ['and', 'i', 'hate', 'that', 'you', 'do', "n't", 'think', 'i', 'belong', 'to', 'ya']
# ['fuckin', "'", 'on', 'the', 'low', ',', 'smokin', "'", 'on', 'the', 'low']
# ['take', 'you', 'to', 'the', 'mall', 'and', 'get', 'you', 'a', 'new', 'outfit']
# ['yours', 'truly', ',', 'the', 'boy']
# []
# ['i', 'do', "n't", 'take', 'naps']
# ['i', 'need', 'someone', 'different']
# ['you', 'know', 'how', 'that', 'should', 'go']
# ['you', 'better', 'do', 'what', 'you', 'supposed', 'to', 'do']
# []
# ['they', 'know', ',', 'they', 'know', ',', 'they', 'know']
# ['smoking', 'weed', 'under', 'star', 'projectors']
# ['yeah', ',', 'but', 'it', "'s", 'weighin', "'", 'heavy', 'on', 'my', 'conscience']
# ['nigga', ',', '"', 'just', '-', 'because', '"', 'song']
# ['you', "'re", 'the', 'girl', ',', 'you', "'re", 'the', 'one']
# ['she', 'used', 'to', 'say', ':', '"', 'you', 'can', 'be', 'whoever', 'you', 'want', ',', 'even', 'yourself', '"']
# []
# ['you', 'get', 'high', 'and', 'do', 'the', 'most', ',', 'yeah']
# ['(', 'and', 'we', 'say', 'hell', 'yeah', ',', 'hell', 'yeah', ',', 'hell', 'yeah']
# ['got', 'ta', 'make', 'that', 'jump', ',', 'got', 'ta', 'make', 'that', ',', 'got', 'ta', ',', 'got', 'ta', 'make', 'that']
# []
# ['remember', '?', 'remember', '?', 'mothafucka', ',', 'remember', '?']
# ['when', 'i', 'was', 'on', 'a', 'mission', 'to', 'make', 'it']
# ['you', 'act', 'so', 'different', 'around', 'me']
# ['i', 'just', 'love', 'when', 'i', "'m", 'with', 'you', ',', 'yeah', ',', 'this', 'shit', 'is', 'on', 'ten']
# ['you', 'do', "n't", 'care', ',', 'if', 'you', "'re", 'true']
# ['all', 'repping', 'one', 'thing']
# ['naked', 'women', 'swimmin', "'", ',', 'that', "'s", 'just', 'how', 'i', "'m", 'livin', "'"]
# ['girl', 'that', "'s", 'just', 'some', 'child', "'s", 'play']
# ['i', 'been', 'steph', 'curry', 'with', 'the', 'shot']
# []
# ['first', '-', 'last', ',', 'phone', 'bill', ',', 'car', 'note', ',', 'cable']
# ['if', 'i', 'die', ',', 'all', 'i', 'know', 'is', 'i', "'m", 'a', 'mothafuckin', "'", 'legend']
# ['every', 'day', ',', 'every', 'day', ',', 'fuck', 'what', 'anybody', 'say']
# ['i', 'am', 'a', 'reflection', 'of', 'all', 'of', 'your', 'insecurities']
# ['i', 'know', 'that', 'you', "'re", 'out', 'here']
# ['when', 'all', 'the', 'baggage', 'just', 'ai', "n't", 'as', 'heavy']
# ['so', 'everywhere', 'we', 'go', 'now', ',', 'full', 'cup']
# ['fuck', 'that', ',', 'never', 'mind', 'what', 'i', 'got']
# []
# ['angels', 'protect', 'you']
# ['we', 'took', 'a', 'picture', 'together', ',', 'i', 'hope', 'she', 'frames', 'it', '!']
# ['i', 'get', 'a', 'ring', 'and', 'i', 'bring', 'it', 'home', 'like', 'i', '’m', 'cory', 'joe']
# ['nope', ',', 'no', 'way', ',', 'nah']
# []
# ['you', 'would', 'love', 'it', 'if', 'i', 'went', 'away', 'or', 'did', 'n’t', 'say', 'nothing', 'else']
# []
# ['i', "'ve", 'had', 'sex', 'four', 'times', 'this', 'week', ';', 'i', "'ll", 'explain']
# []
# ['they', 'want', 'me', 'gone', ',', 'wait', 'for', 'the', 'kicker']
# ['and', 'you', 'do', "n't", 'feel', 'no', 'way', ',', 'you', 'think', 'i', 'deserve', 'it']
# ['i', 'ai', "n't", 'trippin', "'", ',', 'let', "'em", 'rest', 'in', 'peace']
# ['real', 'quick', ',', 'whole', 'squad', 'on', 'that', 'real', 'shit']
# ['got', 'everything', ',', 'i', 'got', 'everything']
# ['care', 'for', 'me', ',', 'care', 'for', 'me', ',', 'i', 'know', 'you', 'care', 'for', 'me']
# ['rather', 'hear', 'how', 'you', 'got', 'it', 'over', ',', 'how', 'much', 'it', 'cost', 'you']
# ['oh', 'ho', ',', 'you', 'know', 'it', ',', 'we', 'both', 'know', 'it']
# ['you', 'used', 'to', 'call', 'me', 'on', 'my']
# ['yeah', ',', 'who', 'gassed', 'you', 'to', 'play', 'with', 'me', '?']
# ['we', 'gon', 'na', 'be', 'in', 'some', 'trouble', ',', 'trouble']
# ['that', "'s", 'why', 'you', 'trust', 'me', ',', 'i', 'know', 'you', 'been', 'through', 'more', 'than', 'most', 'of', 'us']
# ['and', 'i', 'say', 'hell', 'yeah', ',', 'hell', 'yeah', ',', 'hell', 'yeah']
# ['when', 'they', 'need', 'a', 'favor', 'from', 'your', 'man', ',', 'they', 'do', "n't", 'leave', 'you', 'alone']
# ['"', 'pop', '-', 'some', '-', 'fucking', '-', 'champagne', '-', 'in', '-', 'the', '-', 'tub', '"', 'song']
# ['but', 'that', "'s", 'what', 'you', 'do', 'when', 'the', 'money', 'down']
# ['we', 'live', 'in', 'a', 'generation', 'of', 'not', 'being', 'in', 'love', ',', 'and', 'not', 'being', 'together']
# ['mothafuckas', 'never', 'loved', 'us', '!', 'man', ',', 'mothafuckas', 'never', 'loved', 'us']
# ['i', 'got', 'a', '150,000', 'dollars', 'for', 'an', 'afterparty']
# ['pay', 'fi', 'yuh', 'visa', 'meck', 'yo', 'fly', 'out', 'regular']
# ['started', 'from', 'the', 'bottom', ',', 'now', 'we', "'re", 'here']
# ['16', '.', 'lose', 'you']
# ['girl', 'you', 'know', 'we', 'got', 'thangs', 'to', 'do']
# ['my', 'spirit', 'did', 'it', ',', 'i', "'m", 'fearless', 'with', 'it', ',', 'yeah']
# ['make', 'me', 'call', 'my', 'bros', 'for', 'assistance']
# ['i', 'dedicate', ',', 'i', 'dedicate', ',', 'oh', 'yeah']
# ['and', 'that', 'just', 'did', "n't", 'sit', 'right', 'with', 'you']
# ['same', 'city', ',', 'same', 'friends', 'if', 'you', "'re", 'looking']
# ['i', 'wanna', 'see', 'my', 'brothers', 'flourish', 'to', 'they', 'higher', 'purpose']
# ['they', 'do', "n't", 'know', 'they', 'got', 'to', 'be', 'faster', 'than', 'me', 'to', 'get', 'to', 'me']
# ['man', ',', 'you', 'might', "'ve", 'sold', 'to', 'college', 'kids', 'for', 'nike', 'and', 'mercedes']
# ['man', ',', 'someone', 'just', 'gave', 'you', 'the', 'run', '-', 'around']
# ['whoever', 'supposedly', 'makin', "'", 'me', 'hits']
# ['hidden', 'hills', 'where', 'i', 'post']
# ['and', 'they', 'do', "n't", 'have', 'no', 'award', 'for', 'that']
# ['and', 'it', "'s", 'just', 'words', 'and', 'they', 'cut', 'deep']
# ['like', 'controlla', ',', 'controlla', ',', 'yeah']
# ['i', 'did', 'not', 'sign', 'up', 'for', 'this']
# ['music', 'a', 'drop', '!']
# ['i', 'bought', 'this', 'one', 'a', 'house', ',', 'i', 'bought', 'this', 'one', 'a', 'mall']
# ['i', 'know', 'you', 'heard', 'things']
# []
# ['oh', ',', 'you', 'need', 'better', 'seatin', "'"]
# []
# ['higher', 'powers', 'taking', 'a', 'hold', 'on', 'me']
# ['and', 'hold', 'him', 'back', "'cause", 'he', 'makes', 'me', 'nervous']
# ['okay']
# ['last', 'night', 'i', 'brought', 'doa', 'to', 'the', 'studio']
# ['i', 'do', "n't", 'wanna', 'fight', 'it']
# ['i', "'m", 'on', 'my', 'worst', 'behavior', '!', 'do', "n't", 'you', 'ever', 'get', 'it', 'fucked', 'up', '!']
# ['free', 'smoke', ',', 'free', 'smoke', ',', 'ayy', '!']
# []
# ['these', 'days', ',', 'i', 'could', 'probably', 'pack', 'it', 'for', 'like', 'twenty', 'nights', 'if', 'i', 'go', 'in', 'there']
# ['and', 'that', "'s", 'when', 'she', 'text', 'me', 'and', 'told', 'me', 'she', 'prayed', 'it']
# ['i', "'m", 'just', 'sayin', "'", 'you', 'could', 'do', 'better']
# ['this', 'a', '"', 'fuck', '-', 'a', '-', 'stripper', '-', 'on', '-', 'the', '-', 'mink', '-', 'rug', '"', 'song']
# ['looking', ',', 'looking']
# ['fuck', 'with', 'all', 'the', 'word', 'of', 'mouth']
# ['big', 'girls', 'all', 'get', 'a', 'little', 'taste']
# ['mothafucka', ',', 'i', 'done', 'grown', 'up']
# ['it', "'s", 'women', 'to', 'call', ',', 'there', "'s", 'albums', 'to', 'drop']
# ['tuck', 'my', 'napkin', 'in', 'my', 'shirt', ',', '‘', 'cause', 'i', "'m", 'just', 'mobbin', "'", 'like', 'that']
# ['i', "'ll", 'compromise', 'if', 'i', 'have', 'to', ',', 'i', 'got', 'ta', 'stay', 'with', 'the', 'family']
# ['just', 'only', '"', 'hello', '"', 'or', 'a', '"', 'happy', 'belated', '"']
# ['and', 'if', 'somehow', 'you', 'knew']
# ['man', ',', 'i', "'m", 'only', 'twenty', '-', 'nine', ',', 'have', 'some', 'patience', 'with', 'us']
# ['feel', 'like', 'my', 'love', 'life', 'is', 'finished']
# ['but', 'jealousy', 'is', 'just', 'love', 'and', 'hate', 'at', 'the', 'same', 'time']
# ['i', "'m", 'finna', 'do', 'what', 'i', 'did', "n't", 'do']
# ['’cause', 'we', "'re", 'fallin', '’', 'apart']
# ['but', 'we', 'sure', 'make', 'it', 'feel', 'like', 'we', "'re", 'together']
# ['this', 'has', 'been', 'years', 'in', 'the', 'makin', "'"]
# ['it', "'s", 'a', 'east', 'side', 'ting', ',', 'eh', '?']
# ['i', "'m", 'just', 'like', 'a', 'baby', ',', 'droolin', "'", 'over', 'you']
# ['i', "'ll", 'do', 'it', 'for', 'you', 'niggas', 'and', 'do', 'it', 'for', 'myself']
# ['came', 'up', ',', 'that', "'s", 'all', 'me', ',', 'stay', 'true', ',', 'that', "'s", 'all', 'me']
# ['why', 'second', 'guess', '?', 'i', 'should', 'have', 'stayed']
# ['i', 'think', 'i', "'d", 'die', 'for', 'you']
# ['i', 'understand']
# ['shit', '...']
# ['omg', ',', 'niggas', 'sleep', ',', 'i', 'ai', "n't", 'trippin', "'", ',', 'i', "'m", 'a', 'let', "'em", 'sleep']
# ['seasons', 'go', 'by', 'like', 'i', "'m", 'binge', '-', 'watchin', "'"]
# ['niggas', 'takin', "'", 'cheap', 'shots', 'on', 'some', 'cheap', 'shit', '(', '21', ')']
# ['i', 'think', 'maybe', 'i', 'was', 'numb', 'to', 'it', 'last', 'year']
# ['give', 'to', 'me', ',', 'give', 'to', 'me', ',', 'why', 'wo', "n't", 'you', 'live', 'for', 'me', '?']
# ['my', 'ex', 'asked', 'me', ',', '"', 'where', 'you', 'movin', "'", '?', '"', 'i', 'said', ',', '"', 'on', 'to', 'better', 'things', '"']
# ['last', 'night', ',', 'i', 'got', 'high', 'as', 'your', 'expectations']
# ['baby', ',', 'i', 'like', 'your', 'style']
# ['i', 'been', 'in', 'the', 'crib', 'with', 'the', 'phones', 'off']
# ['yeah', ',', 'bounce', 'that', 'shit', 'like', 'woah']
# ['shit', 'ai', "n't", 'been', 'the', 'same', 'like', 'before']
# ['do', "n't", 'come', 'around', 'thinkin', "'", 'you', 'gettin', "'", 'saved']
# ['back', ',', 'up', ',', 'back', 'up', 'and', 'wine', 'it', ',', 'girl']
# ['500', 'million', ',', 'i', 'got', 'a', 'pound', 'cake']
# ['i', 'do', "n't", 'even', 'know', 'how', 'much', 'i', 'really', 'made', ',', 'i', 'forgot', ',', 'it', "'s", 'a', 'lot']
# ['girl', 'you', 'know', 'we', 'got', 'thangs', 'to', 'do']
# ['i', 'just', 'take', 'my', 'time', 'with', 'all', 'this', 'shit', ',', 'i', 'still', 'believe', 'in', 'that']
# ['do', 'things', 'when', 'you', 'want', 'me', 'too']
# []
# []
# []
# ['like', 'a', 'motherfucking', 'drive', '-', 'thru']
# ['young', 'rebel', ',', 'young', 'money', "nothin'", 'you', 'could', 'tell', 'me']
# ['right', 'or', 'wrong', ',', 'i', "'m", 'a', 'write', 'my', 'wrongs']
# ['and', 'we', 'say', 'hell', 'yeah', ',', 'hell', 'yeah', ',', 'hell', 'yeah']
# ['they', 'do', 'n’t', 'want', 'us', 'to', 'have', 'a', 'bigger', 'pool', 'than', 'kanye']
# ['on', 'a', 'mission', 'tryna', 'shift', 'the', 'culture']
# ['this', 'for', "y'", 'all', 'that', 'think', 'that', 'i', 'do', "n't", 'write', 'enough']
# ['that', 'can', 'only', 'mean', 'one', 'thing']
# ['i', 'got', 'niggas', 'that', '’ll', 'still', 'try', 'fuckin', '’', 'me', 'over']
# ['paranoid', ',', 'always', 'rolling', 'with', 'my', 'mothafuckin', "'", 'boys']
# ['i', 'ca', "n't", 'blame', 'you', ',', 'no', ',', 'no']
# ['skrrt', 'skrrt']
# ['i', 'ca', "n't", 'even', 'listen', ',', 'you', 'wildin', "'"]
# ['i', 'do', "n't", 'trust', 'a', 'word', 'you', 'say']
# ['cause', 'we', '—']
# ['i', "'ll", 'be', 'here', 'just', 'swanging']
# ['and', 'we', 'never', 'talk', 'too', 'much', 'after', 'i', 'blew', 'up']
# ['that', "'s", 'word', 'to', 'my', 'nigga']
# ['guess', 'whose', 'it', 'is', '?', 'it', "'s", 'yours']
# ['young', 'nigga', 'came', 'through', 'on', 'his', 'wu', '-', 'tang']
# ['just', 'know', 'that', 'these', 'streets', 'just', 'do', "n't", 'love', 'you', 'like', 'i', 'do']
# ['one', 'more', 'time', "'", 'fore', 'i', 'go']
# ['go', 'uptown', ',', 'new', 'york', 'city', ',', 'bitch']
# []
# ['a', 'couple', 'somebodies', 'started', 'killin', "'", 'themself']
# ['i', 'reach', 'back', 'like', 'one', ',', 'three']
# ['talk', 'if', 'you', 'need', 'to', ',', 'but', 'i', 'ca', "n't", 'stay', 'to', 'hear', 'you']
# ['ex', '-', 'girl', ',', 'she', 'the', 'female', 'version', 'of', 'me']
# ['free', 'smoke', ',', 'free', 'smoke']
# ['passive', 'aggressive', 'when', 'we', "'re", 'texting', ',', 'i', 'feel', 'the', 'distance']
# []
# ['put', 'a', 'bib', 'on', 'me']
# ['let', "'s", 'just', 'not', 'even', 'discuss', 'it', ',', 'man']
# ['you', 'really', 'pipin', "'", 'up', 'on', 'these', 'niggas']
# ['ya', 'dun', 'know', ',', 'eh', '?']
# ['why', 'the', 'sudden', 'change', '?']
# ["'cause", 'i', "'m", 'up', 'right', 'now', ',', 'and', 'you', 'stuck', 'right', 'now']
# ['world', "'s", ',', 'world', "'s", ',', 'world', "'s", 'famous']
# []
# []
# ['and', 'they', 'want', 'to', 'see', 'me', 'pick', 'back', 'up', ',', 'well', ',', 'where', "'d", 'i', 'leave', 'it', 'at', '?']
# ['dealing', 'with', 'a', 'heart', 'that', 'i', 'did', "n't", 'break']
# ['i', 'need', 'a', 'fuelband', 'just', 'to', 'see', 'how', 'long', 'the', 'run', 'has', 'been']
# ['(', 'fuck', 'niggas', 'gon', "'", 'be', 'fuck', 'niggas']
# ['stay', 'fly', ',', 'it', "'s", 'jet', 'time', '–', 'stunt', ',', 'nigga', '!']
# ['i', 'just', 'been', 'playing', ',', 'i', 'ai', "n't", 'even', 'notice', 'i', 'was', 'winning']
# ['girl', 'you', 'know', 'we', 'got', 'thangs', 'to', 'do']
# ['yeah', ',', 'i', 'guess', 'that', "'s", 'just', 'who', 'i', 'became', ',', 'dawg']
# ['remember', '?', 'mothafucka', 'never', 'loved', 'us']
# ['and', 'if', 'somehow', 'you', 'knew']
# ['man', ',', 'this', 'shit', 'is', 'not', 'a', 'love', 'song']
# ['oh', ',', 'the', 'idea', 'is', 'fun', ',', 'oh', ',', 'the', 'idea', 'is', 'fun']
# []
# ['girl', ',', 'i', "'m", 'sleepy']
# ['they', 'know', ',', 'they', 'know', ',', 'they', 'know']
# ['she', 'said', ',', '"', 'do', 'you', 'love', 'me', '?', '"', 'i', 'tell', 'her', ',', '"', 'only', 'partly', '"']
# ['then', 'tell', 'that', 'man', 'to', 'ease', 'up']
# ['cry', 'for', 'me', ',', 'cry', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'die', 'for', 'me']
# ['i', 'just', 'do', "n't", 'understand', 'it']
# ['would', 'you', 'lie', 'to', 'me', '?']
# ['yeah', ',', 'slightly', 'took', 'a', 'left', 'turn', 'there']
# ['my', 'actions', 'been', 'louder', 'than', 'my', 'words', ',', 'nigga']
# ['they', 'loving', 'the', 'crew']
# []
# ['they', 'tryna', 'take', 'the', 'wave', 'from', 'a', 'nigga']
# ['bury', 'me', 'now', 'and', 'i', 'only', 'get', 'bigger']
# ['got', 'ta', 'do', 'what', 'i', 'got', 'ta', 'do']
# ['and', 'since', 'you', 'picked', 'up', ',', 'i', 'know', 'he', "'s", 'not', 'around']
# ["'cause", 'you', 'know', 'i', "'m", 'okay']
# ['bring', 'us', 'up', ',', 'i', 'never', 'take', 'us', 'down']
# ["'cause", 'i', "'m", 'up', 'right', 'now', ',', 'and', 'you', 'stuck', 'right', 'now', ',', 'yeah']
# ['i', 'wanna', 'know', 'how', 'much', 'time', 'you', 'spent', 'on', 'them', 'paragraphs']
# ['could', 'it', 'be', 'the', 'way', 'that', 'i', "'ll", 'catch', 'up']
# ['and', 'she', 'textin', "'", 'purple', 'hearts', "'cause", 'she', 'know', 'that', 'we', 'at', 'war', ',', 'yuh']
# ['i', 'am', 'the', 'kid', 'with', 'the', 'motor', 'mouth']
# ['years', 'go', 'by', 'too', 'fast']
# ['dissin', "'", 'but', 'got', 'pictures', 'with', 'me', 'smilin', "'", 'though']
# ['jodeci', '"', 'cry', 'for', 'you', '"']
# ['i', "'m", 'the', 'fuckin', "'", 'man', ',', "y'", 'all', 'do', "n't", 'get', 'it', ',', 'do', 'ya', '?']
# ['that', "'s", 'a', 'bold', 'move']
# ['if', 'she', "'s", 'at', 'the', 'game']
# ['she', 'rode', 'it', 'like', 'a', 'soldier']
# []
# ['open', 'cases', 'on', 'me', 'for', 'a', 'half', 'a', 'million', 'each']
# ['when', 'i', 'could', 'tell', 'it', 'was', 'sincere', 'without', 'tryna', 'prove', 'it']
# ['i', 'get', 'boxes', 'of', 'free', 'jordan', 'like', 'i', 'play', 'for', 'north', 'carolina']
# ['i', 'get', 'more', 'satisfaction', 'outta', "goin'", 'at', 'your', 'head']
# ['all', 'up', 'on', 'tv', ',', 'i', 'thought', 'it', "'d", 'make', 'me', 'richer']
# ['shit', 'got', 'me', 'feeling', 'pinned', 'down', ',', 'pick', 'the', 'pen', 'up', 'or', 'put', 'the', 'pen', 'down']
# ['rich', 'enough', 'that', 'i', 'do', "n't", 'have', 'to', 'tell', "'em", 'that', 'i', "'m", 'rich']
# ['there', 'for', 'me', ',', 'there', 'for', 'me', ',', 'said', 'you', "'d", 'be', 'there', 'for', 'me', '(', 'yeah', ')']
# ['tryna', 'give', 'your', 'ass', 'the', 'world']
# ['i', 'guess', 'it', 'really', 'is', 'just', 'me', ',', 'myself', 'and', 'all', 'my', 'millions']
# ['yeah']
# []
# ['hell', 'nah']
# ['machine', 'gun', 'raps', 'for', 'all', 'my', 'niggas', 'in', 'the', 'back']
# ['and', 'all', 'my', 'family', 'from', 'the', 'm', '-', 'town', 'that', 'i', "'ve", 'been', "'", 'round', ',', 'started', 'treating', 'me', 'like', 'i', "'m", '"', 'him', '"', 'now']
# ['worst', '...']
# ['without', '40', ',', 'oli', ',', 'there', '’d', 'be', 'no', 'me']
# ['14', '.', 'teenage', 'fever']
# ['cause', 'the', 'new', 'drugs', 'got', 'the', 'kids', 'trippin', "'", 'these', 'days']
# ['runnin', "'", 'through', 'the', '6', 'with', 'my', 'woes']
# []
# ['had', 'us', 'fooled', 'for', 'a', 'minute', 'there', ',', 'now', 'we', 'done', 'all', 'grown', 'up']
# ['so', 'you', 'ca', "n't", 'drive', 'it', ',', 'and', 'put', 'on', 'mileage']
# ['girl', 'you', 'know', 'that', 'i', 'remember', ',', 'do', "n't", 'be', 'a', 'pretender']
# ['god', "'s", 'plan', ',', 'god', "'s", 'plan']
# ['we', 'already', 'got', 'spring', '2015', 'poppin', "'"]
# ['i', "'ve", 'been', 'down', 'so', 'long', ',', 'it', 'look', 'like', 'up', 'to', 'me']
# ['she', 'rode', 'it', 'like', 'a', 'soldier']
# ['me', ',', 'franny', ',', 'and', 'mally', 'mall', 'at', 'the', 'crib', '-', 'o']
# []
# ['i', 'had', 'to', 'let', 'go', 'of', 'us', 'to', 'show', 'myself', 'what', 'i', 'could', 'do']
# []
# ['rolling', 'swishers', ',', 'hittin', "'", 'swishes']
# ['and', 'my', 'father', 'living', 'in', 'memphis', 'now', ',', 'he', 'ca', "n't", 'come', 'this', 'way']
# ['yeah', ',', 'these', 'days', 'i', 'do', "n't", 'know', 'how', 'to', 'talk', 'to', 'you']
# ['like', 'i', 'did', "n't", 'make', 'that', 'clearer', 'this', 'year']
# ['i', 'ca', "n't", 'keep', 'track']
# ['straight', 'up', 'to', 'my', 'face', ',', 'straight', 'up', 'to', 'my', 'face']
# ['and', 'eat', 'with', 'italians', ',', 'i', 'do']
# ['fuck', 'that', ',', 'never', 'mind', 'what', 'i', 'got']
# ['i', "'m", 'on', 'my', 'motherfuckin', "'", 'way', 'swangin', "'"]
# ['time', 'escapes', 'me']
# ['but', 'maybe', 'i', 'ai', "n't", 'lose', "'em", 'at', 'all']
# ['but', 'you', 'been', 'missin', "'", 'girl', 'and', 'you', 'might', 'feel', 'like', "nothin'", 'was', 'the', 'same']
# ['10', 'bands', ',', '50', 'bands', ',', '100', 'bands', ',', 'fuck', 'it', ',', 'man']
# ['20', '.', 'fake', 'love']
# ['but', 'if', 'i', 'stay', ',', 'then', 'this', 'shit', 'is', 'a', 'bunch', 'of', 'corpses']
# ['i', 'got', 'fake', 'people', 'showin', "'", 'fake', 'love', 'to', 'me']
# []
# ['i', 'got', 'real', 'ones', 'livin', '’', 'past', 'kennedy', 'road']
# ['yeah', ',', 'this', 'that', 'oliver', ',', '40', ',', 'niko', 'shit', 'man']
# ['and', 'i', "'d", 'allow', 'her', ',', 'talk', 'about', 'pussy', 'power']
# ['you', "'ve", 'seen', 'all', 'my', 'mistakes', 'so', 'look', 'me', 'in', 'my', 'eyes']
# ['that', "'s", 'just', 'how', 'i', "'m", 'givin', "'", 'it', 'up']
# ['there', 'ai', "n't", 'really', 'much', 'out', 'here', 'that', "'s", 'poppin', "'", 'off', 'without', 'us']
# ['got', 'my', 'whole', 'crew', 'blowing', 'like', 'a', 'c4']
# ['they', 'loving', 'the', 'crew']
# ['the', 'nerve', ',', 'the', 'audacity']
# ['it', "'s", 'funny', 'when', 'you', 'think', 'a', 'nigga', 'blew', 'up', 'after', 'lupe']
# ['bitches', 'in', 'my', 'old', 'phone']
# ['if', 'you', 'had', 'my', 'love']
# ['i', 'am', 'the', 'one', 'you', 'should', 'worry', "'bout"]
# ['girl', ',', 'how', "'bout", 'now', ',', 'how', "'bout", 'now', ',', 'girl', '?']
# ['they', 'know', ',', 'they', 'know', ',', 'they', 'know']
# []
# ['thank', 'you', ',', 'thanks', ',', 'drake', ',', 'thanks', 'baby']
# ['okay', ',', 'made', 'a', 'million', ',', 'off', 'a', 'dinner', 'fork', ',', 'watch', 'me', 'switch', 'it', 'up']
# ['cleansin', "'", 'my', 'soul', 'of', 'addiction', 'for', 'now']
# []
# ['you', 'probably', 'do', "n't", 'remember', 'half', 'the', 'shit', 'a', 'nigga', 'did', 'for', 'you']
# ['cash', 'rules', 'everything', 'around', 'me']
# ['there', "'s", 'no', 'need', 'for', 'us', 'to', 'rush', 'it', 'through', ',', 'ohhh']
# ['cry', 'for', 'me', ',', 'cry', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'die', 'for', 'me']
# []
# ['and', 'sitting', 'talking', "'bout", 'bitches', 'that', 'we', 'almost', 'had']
# ['must', "'ve", 'had', 'your', 'infrared', 'wrong', ',', 'now', 'your', 'head', 'in', 'the', 'beam']
# ['got', 'ta', 'hit', 'the', 'club', 'like', 'you', 'hit', 'them', ',', 'hit', 'them', ',', 'hit', 'them', 'angles']
# []
# ['and', 'show', 'me', 'pictures', 'of', 'they', 'friends']
# ['landmarks', 'of', 'the', 'muses', 'that', 'inspired', 'the', 'music']
# ['i', 'give', 'a', 'fuck', 'about', 'old', 'boy', '(', 'man', 'that', 'boy', 'old', ')']
# ['to', 'do', 'what', 'you', 'could', "n't", 'do']
# ['playin', "'", 'mime', 'games', ',', 'we', 'both', "doin'", 'the', 'same', 'thing']
# ['now', 'you', 'poppin', "'", 'up', 'with', 'the', 'jokes', ',', 'i', "'m", 'dead', ',', 'i', "'m", 'asleep']
# ['i', 'been', 'movin', "'", 'calm', ',', 'do', "n't", 'start', 'no', 'trouble', 'with', 'me']
# ['wholehearted', ',', 'wholehearted', ',', 'you', 'care', ',', 'you', 'care']
# ['i', 'dedicate', ',', 'i', 'dedicate']
# ['i', 'need', 'someone', 'i', 'leave', 'through', 'the', 'front', 'door', 'with']
# ['we', 'too', 'deep', 'in', 'this', 'thing', ',', 'you', "'ll", 'never', 'lose', 'me']
# ['play', 'this', 'shit', 'at', 'my', 'funeral', 'if', 'they', 'catch', 'me', 'slippin', "'"]
# ['i', 'dedicate', ',', 'i', 'dedicate']
# []
# ['yeah', ',', 'i', 'mean', 'you', 'already', 'wrote', 'for', 'us']
# ['yeah', ',', 'you', 'know', 'wassup', '(', 'yeah', ')']
# ['this', 'song', "'s", 'for', 'you']
# ['a', 'shot', 'for', 'me']
# ['had', 'all', 'this', 'fighting', 'going', 'on', 'at', 'the', 'crib']
# ['me', 'and', 'my', 'broski', 'are', 'twins', ',', 'but', 'we', 'do', "n't", 'look', 'alike']
# ['tired', 'of', 'sittin', "'", 'quiet', 'and', 'helpin', "'", 'my', 'enemies', 'eat']
# ['probably', 'making', 'more', 'money', 'than', 'me', 'and', 'shit']
# ...
# ['hate', 'the', 'fact', 'my', 'mom', 'cooped', 'up', 'in', 'her', 'apartment', ',', 'telling', 'herself']
# ['but', 'i', "'ve", 'been', 'drinkin', "'", 'so', 'much']
# ['i', "'ve", 'had', 'mine', ',', 'you', "'ve", 'had', 'yours', ',', 'we', 'both', 'know', '..', 'we', 'know']
# ['and', 'now', 'you', 'hate', 'me', ',', 'stop', 'pretendin', "'", ',', 'stop', 'that', 'frontin', "'", ',', 'i', 'ca', "n't", 'take', 'it']
# ['you', 'gon', "'", 'make', 'me', 'step', 'out', 'of', 'my', 'fuckin', "'", 'frame']
# ['i', 'want', 'to', 'see', 'my', 'dog', ',', 'but', 'his', 'grandmother', "'s", 'his', 'surety']
# ['come', 'live', 'all', 'your', 'dreams', 'out', 'at', 'ovo']
# ['you', 'act', 'so', 'different', 'around', 'me']
# ['i', 'got', 'fake', 'people', 'showin', "'", 'fake', 'love', 'to', 'me']
# ['every', 'single', 'round', "y'", 'all']
# ['cry', 'for', 'me', ',', 'cry', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'die', 'for', 'me']
# ['you', 'getting', 'money', '?']
# ['i', 'be', 'there', 'for', 'you', ',', 'i', 'will', 'care', 'for', 'you']
# ['and', 'i', ',', 'i', 'wish', 'time', 'never', 'mattered']
# []
# ['running', 'out', 'of', 'pages', 'in', 'your', 'passport']
# []
# ['you', 'never', 'believe', 'me']
# []
# ['done', 'talk', 'now', ',', "'cause", 'there', "'s", 'other', 'shit', 'that', "'s", 'concernin', "'", 'me']
# ['they', 'tell', 'him', 'that', 'he', "'s", 'talkin', "'", 'crazy', 'but', 'he', 'does', "n't", 'care']
# ['are', 'you', 'down', '?', 'are', 'you', 'down', '?', 'are', 'you', 'down', '?']
# ["'", 'bout', 'the', 'shit', 'that', 'i', 'been', 'through']
# ['i', "'m", 'just', 'gettin', "'", 'started', ',', 'oh', ',', 'yeah', ',', 'we', 'got', 'it', 'bitch']
# ['you', 'got', 'the', "goin'", 'out', 'sad', 'bitches']
# ['i', 'do', "n't", 'have', 'a', 'fuck', 'to', 'give', ',', 'i', "'ve", 'been', 'moving', 'state', 'to', 'state']
# ['you', 'was', 'never', 'gang', ',', 'gang', ',', 'gang', ',', 'gang', ',', 'you', 'was', 'never', 'one', 'of', 'us']
# ['(', 'oh', 'ho', ',', 'oh', 'ho', ')']
# ['you', 'make', 'me', 'feel', 'like', 'i', 'did', 'you', 'wrong']
# ['girl', 'you', 'know', 'we', 'got', 'thangs', 'to', 'do']
# ['comin', "'", 'live', 'from', 'the', 'screwface', ',', 'livin', "'", 'out', 'a', 'suitcase']
# ['own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it', ',', 'own', 'it']
# ['and', 'i', 'met', 'your', 'baby', 'moms', 'last', 'night']
# ['you', 'say', ',', '"', 'a', 'guarantee', '"']
# ['and', 'i', "'m", 'still', 'in', 'love', ',', "'", 'cus', 'when', 'it', "'s", 'that', 'real']
# ['wo', "n't", 'knock', 'on', 'your', 'door']
# ['yeah', ',', 'just', 'a', 'young', 'kid', 'in', 'a', 'drop', 'top']
# ['and', "nothin'", 'was', 'the', 'same']
# ['bury', 'me', 'now', 'and', 'i', 'only', 'get', 'bigger']
# []
# ['you', 'need', 'that', 'work', ',', 'i', 'got', 'that', 'work', ',', 'got', 'bitches', 'in', 'my', 'condo']
# ['contract', 'max', ',', 'i', 'got', 'ta', 'bring', 'that', 'shit', 'back']
# ['there', 'for', 'me', ',', 'there', 'for', 'me', ',', 'said', 'you', "'d", 'be', 'there', 'for', 'me']
# ['but', 'still', 'i', 'ca', "n't", 'deny', 'the', 'fact', 'that', 'it', "'s", 'true']
# ['worst', 'behavior', '!', 'mothafuckas', 'never', 'loved', 'us']
# ['he', 'was', 'comin', "'", 'to', 'the', 'house', 'to', 'get', 'me']
# ['could', 'it', 'be', 'the', 'way', 'that', 'i', "'ll", 'catch', 'up']
# ["y'all", 'keep', 'playin', "'", 'with', 'your', 'nose', ',', 'yeah']
# ['with', 'no', 'apology', ',', 'if', 'you', 'nuh', 'like', 'we', ',', 'we', 'nuh', 'like', 'you', 'neither', 'youth']
# ['do', "n't", 'fuck', 'with', 'them', 'niggas', ',', 'they', 'too', 'irrational', ',', 'woah']
# ['damn', 'that', '’s', 'a', 'motherfucker']
# ['and', 'you', 'showin', "'", 'off', ',', 'but', 'it', "'s", 'alright', '(', 'alright', '!', ')']
# ['they', 'ai', "n't", 'even', 'wanna', 'look', 'up', 'at', 'the', 'score']
# ['so', 'cry', 'if', 'you', 'need', 'to', ',', 'but', 'i', 'ca', "n't", 'stay', 'to', 'watch', 'you']
# ['david', 'blaine', 'last', 'summer', ',', 'man', ',', 'you', 'had', 'to', 'vanish']
# ['still', 'getting', 'brain', 'from', 'a', 'thang', ',', 'ai', "n't", 'shit', 'changed']
# ['is', 'this', 'shit', 'real', '?', 'should', 'i', 'pinch', 'you', '?']
# ['so', 'now', 'i', "'m", 'all', 'in', 'niko', "'s", 'basement', 'puttin', "'", 'work', 'in', 'on', 'the', 'phones']
# ['i', "'ll", 'admit', 'it', ',', 'i', "'ll", 'admit', 'it', '(', 'ga', ',', 'grrra', 'ga', 'ga', 'ga', 'ga', ')']
# ['even', 'though', 'it', "'s", 'fucked', 'up', ',', 'girl', 'i', "'m", 'still', 'fucking', 'with', 'ya']
# ['i', 'got', 'the', 'drink', 'in', 'me', 'going', 'back', 'to', 'back']
# ['if', 'i', 'was', 'doing', 'this', 'for', 'you', 'then', 'i', "'d", 'have', 'nothing', 'left', 'to', 'prove']
# ['that', 'can', 'only', 'mean', 'one', 'thing']
# ['never', 'let', 'these', 'niggas', 'ride', 'your', 'wave']
# ['may', 'your', 'neighbors', 'respect', 'you']
# ['started', 'from', 'the', 'bottom', ',', 'now', 'we', "'re", 'here']
# ['shakiness', ',', 'man', ',', 'i', 'do', "n't", 'have', 'no', 'time', 'for', 'that']
# ['they', 'shoulda', 'never', 'let', 'you', "'", 'round', 'cake']
# ['why', 'would', 'i', 'put', 'on', 'a', 'vest', '?', 'i', 'expect', 'you', 'to', 'aim', 'for', 'the', 'head']
# ['but', 'we', 'still', 'met', 'later', 'that', 'night']
# ['and', 'i', 'thank', 'you', ',', 'i', 'do', "n't", 'know', 'where']
# ['you', 'dream', 'big', 'and', 'sleep', 'late']
# ['i', 'had', 'benzes', "'", 'fore', 'you', 'had', 'braces']
# ['i', "'ll", 'be', 'there', 'just', 'swangin', "'"]
# ['that', "'s", 'the', 'wrong', 'thing', 'to', 'do']
# ['hoes', 'talk', 'down', ',', 'you', 'do', "n't", 'see', "'em", 'outside']
# []
# ['then', 'kanye', 'dropped', ',', 'it', 'was', 'polos', 'and', 'backpacks']
# ['first', 'i', 'made', 'you', 'who', 'you', 'are', 'and', 'then', 'i', 'made', 'it']
# ['i', "'m", 'just', 'tryna', 'connect', 'with', "somethin'", 'baby']
# ['i', 'ai', "n't", 'even', 'see', 'my', 'friends', 'that', 'year']
# []
# ['even', 'when', 'i', "'m", 'away']
# ['what', "'s", 'a', 'life', 'with', 'no', 'fun', '?', 'please', ',', 'do', "n't", 'be', 'so', 'ashamed']
# []
# ['doing', 'things', 'i', 'taught', 'you', ',', 'gettin', "'", 'nasty', 'for', 'someone', 'else']
# ['give', 'these', 'niggas', 'the', 'look', ',', 'the', 'verse', ',', 'and', 'even', 'the', 'hook']
# ['lying', 'to', 'protect', 'you', ',', 'i', 'be', 'doing', 'that', 'a', 'lot']
# ['looking', ',', 'looking', ',', 'looking']
# ['eatin', "'", 'like', 'i', '’m', 'seated', 'at', 'swish', ',', 'sotto', ',', 'and', 'joso', "'s"]
# ['you', 'do', "n't", 'even', 'know', 'what', 'you', 'want', 'from', 'love', 'anymore']
# ['by', 'some', 'random', 'nigga', 'that', 'live', 'in', 'atlanta']
# ['you', 'do', "n't", 'see', 'anybody', 'else']
# ['i', "'ll", 'be', 'there', 'just', 'swangin', "'"]
# ['same', 'old', 'pimp', ',', 'drake', ',', 'you', 'know', 'ai', "n't", "nothin'", 'changed']
# ['i', 'know', 'that', 'you', "'re", 'out', 'here']
# []
# ['oh', ',', 'you', 'niggas', 'got', 'jokes']
# ['being', 'indecisive', 'makes', 'me', 'anxious']
# ['we', 'eat', 'each', 'other', 'whenever', 'we', 'at', 'the', 'dinner', 'table']
# ['please', ',', 'somebody', 'stop', 'me']
# ['shit', 'is', 'hot', 'up', 'in', 'the', '6', 'right', 'now', '(', 'ga', 'ga', 'ga', ')']
# ['sometimes', 'it', 'be', 'like', 'that']
# ['tell', 'me']
# ['tell', 'me', 'when', 'i', "'m", 'lyin', "'", ',', 'tell', 'me', 'when', 'i', "'m", 'tryin', "'"]
# ['rap', 'game', ',', 'crack', 'game', ',', 'ai', "n't", 'that', 'different', ',', 'ya', 'know', '?']
# ['right', ',', 'my', 'yiy', 'just', 'changed']
# []
# ['what', 'do', 'you', 'really', 'think', 'of', 'the', 'nigga', 'that', "'s", 'makin', "'", 'your', 'beats', '?']
# ['they', 'do', "n't", 'really', 'leave', 'your', 'ass', 'with', 'a', 'mothafuckin', "'", 'choice', ',', 'man']
# ['i', 'can', 'not', 'complain', ',', 'i', 'can', 'not']
# ['come', 'thru', ',', 'come', 'thru', ',', 'come', 'thru', ',', 'come', 'thru']
# ['they', 'loving', 'the', 'crew']
# ['and', 'people', 'be', 'on', 'some', 'weak', 'bitch', 'ass', 'shit', 'all', 'day', 'long']
# ['i', '’m', 'charged', 'up', ',', 'i', '’m', 'charged', 'up']
# ['we', 'used', 'to', 'be', 'friends', ',', 'girl', ',', 'and', 'even', 'back', 'then']
# ["'cause", 'man', 'it', "'s", 'a', 'mission', ',', 'tryna', 'fight', 'to', 'the', 'finish']
# ['come', 'and', 'get', 'it', 'from', 'the', 'source']
# ['is', "n't", 'it', 'amazing', 'how', 'you', 'talk', 'all', 'this', 'shit', 'and', 'we', 'still', 'lack', 'communication']
# ['where', ',', 'where', ',', 'where', ',', 'where']
# ['and', 'you', 'should', "n't", 'miss', "'em", 'either', ',', 'we', 'different', 'people']
# ['i', 'got', 'ta', 'start', 'sleepin', "'", 'at', 'the', 'studio']
# ['and', 'i', 'seen', 'a', 'lot', 'of', 'you', 'die']
# ['um', ',', 'trying', 'to', 'think', 'of', 'the', 'right', 'thing', 'to', 'say']
# ['bad', 'things']
# ['some', 'niggas', 'been', 'here', 'for', 'a', 'couple', ',', 'never', 'been', 'here', 'again']
# ['remember', '?', 'mothafucka', '!']
# ['i', 'do', 'it', 'how', 'you', 'say', 'you', 'want', 'it']
# ['no', 'game', ',', 'no', 'scrimmage', ',', 'i', 'ai', "n't", 'playin', "'", 'with', 'you', 'niggas', 'at', 'all']
# ['always', 'felt', 'like', 'my', 'vision', 'been', 'bigger']
# ['i', 'can', 'almost', 'guarantee', 'she', 'know', 'the', 'deal', ',', 'real', 'nigga', ',', 'what', "'s", 'up', '?']
# ['part', '1', ':', 'pound', 'cake', ',', 'produced', 'by', 'boi-1da', ',', 'matthew', 'burnett', ',', 'and', 'jordan', 'evans']
# ['streets', 'not', 'safe', 'but', 'i', 'never', 'run', 'away']
# ['give', 'to', 'me', ',', 'give', 'to', 'me', ',', 'why', 'wo', "n't", 'you', 'live', 'for', 'me', '?']
# ['you', 'would', 'look', 'at', 'me', 'with', 'no', 'hesitation', 'and', 'you', "'d", 'tell', 'me', 'baby', ',', 'it', "'s", 'yours']
# ['oh', '-', 'oh', ',', 'i', 'guess', 'that', "'s", 'just', 'the', 'motion']
# ['higher', 'powers', 'taking', 'a', 'hold', 'on', 'me']
# ['instead', 'of', 'the', 'other', 'way']
# ['ok', ',', 'look', ',', 'i', "'m", 'honest', '.', 'girl', ',', 'i', 'ca', "n't", 'lie', ',', 'i', 'miss', 'you']
# ['that', 'mean', 'i', "'m", 'way', 'up', '(', 'way', 'up', ')']
# ['lyor', 'made', 'millions', ',', 'cam', 'made', 'millions']
# ['this', 'is', 'why', 'i', '’ve', 'been', 'saying']
# ['you', 'got', 'a', 'different', 'vision']
# []
# ['sinatra', 'lifestyle', ',', 'i', "'m", 'just', 'bein', "'", 'frank', 'with', 'ya']
# ['fucka', 'never', 'loved', 'us', '!', 'worst', 'behavior']
# ['i', "'m", 'just', 'tryna', 'stay', 'alive', 'and', 'take', 'care', 'of', 'my', 'people']
# ['i', "'m", 'a', 'magnet', 'for', 'bad', 'bitches']
# ['nigga', 'do', "n't", 'watch', 'that', "'cause", 'i', '—']
# ['there', 'for', 'me', ',', 'there', 'for', 'me', ',', 'said', 'you', "'d", 'be', 'there', 'for', 'me']
# ['i', "'m", 'so', 'hot', ',', 'yeah', ',', 'i', '’m', 'so', 'right', 'now']
# ['rounds', 'tonight', 'oh', ',', 'come', 'thru', 'girl', 'you', 'deserve', 'rounds', 'tonight']
# ['fuck', 'what', 'they', 'talkin', "'", 'about', 'on', 'your', 'timeline']
# ['yeah', ',', 'going', 'back', 'to', 'back']
# ['hermès', 'link', ',', 'ice', '-', 'blue', 'mink']
# ['cause', 'there', "'s", 'niggas', 'creepin', 'and', 'not', 'like', 'how', 'we', "'re", 'creepin', "'"]
# ['got', 'a', 'hennessy', 'in', 'my', 'hand']
# ['and', 'i', "'m", 'the', 'only', 'nigga', 'still', 'known', 'for', 'the', 'music']
# ['you', 'say', 'the', 'word', ',', 'i', "'m", 'on', 'the', 'way']
# []
# ['ymcmb', ',', 'you', 'niggas', 'more', 'ymca']
# ['that', 'i', 'made', 'it', '?', 'yeah', ',', 'i', 'made', 'it']
# ['and', 'did', 'that', 'shit', "'cause", 'it', "'s", "somethin'", 'to', 'do']
# ['i', 'just', 'fell', 'back', 'with', 'it']
# ['these', 'days', ',', 'i', "'m", 'lettin', "'", 'god', 'handle', 'all', 'things', 'above', 'me']
# ['they', 'look', 'up', 'to', 'me']
# ['say', 'my', 'name']
# []
# []
# ['how', 'many', 'more', 'days', 'could', 'i', 'wait', '?']
# ['they', 'go', 'to', 'school', 'and', 'do', 'bottle', 'service']
# ['you', 'actin', '’', 'kinda', 'shady', ',', 'baby']
# ['bench', 'players', 'talkin', "'", 'like', 'starters', ',', 'i', 'hate', 'it']
# ['then', 'she', 'start', 'telling', 'me', 'how', 'i', "'ll", 'never', 'be', 'as', 'big', 'as', 'trey', 'songz']
# ['care', 'for', 'me', ',', 'care', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'care', 'for', 'me']
# ['take', 'a', 'flick', ',', 'i', 'look', 'like', 'meechy', ',', 'look', 'like', 'bleu', 'davinci']
# []
# ['you', 'knew', 'me', 'when', 'the', 'kid', 'had', 'waves']
# ['i', "'ve", 'been', 'on', 'a', 'mission', ',', 'have', "n't", 'left', 'the', 'condo']
# ['oh', ',', 'they', 'loving', 'the', 'crew']
# ['how', 'you', 'wanna', 'clique', 'up', 'after', 'your', 'mistakes', '?']
# ['red', 'wine', 'over', 'fed', 'time']
# ['1', '.', 'free', 'smoke']
# ['that', 'ovo', 'and', 'that', 'xo', 'is', 'everything', 'you', 'believe', 'in', ',', 'i', 'know']
# []
# ['so', 'what', 'are', 'you', '?', 'what', 'are', 'you', ',', 'what', 'are', 'you', 'so', 'afraid', 'of', '?']
# ['you', 'could', 'never', 'say', 'i', 'came', 'up', 'and', 'forgot', 'about', 'your', 'ass']
# ['i', "'m", 'twisted', ':', 'door', 'knob']
# ['yeah', ',', 'looking', 'back', 'on', 'it', ',', 'at', 'least', 'my', 'pride', 'is', 'intact']
# ['i', 'do', "n't", 'wanna', 'die', 'for', 'them', 'to', 'miss', 'me']
# []
# ['my', 'one', 'button', ',', 'you', 'push', 'it']
# ['come', 'thru', ',', 'come', 'thru', ',', 'come', 'thru', ',', 'come', 'thru']
# ['you', 'only', 'live', 'once', ':', 'that', "'s", 'the', 'motto', ',', 'nigga', ',', 'yolo']
# ['and', 'this', 'ai', 'n’t', 'no', 'time', 'for', 'games']
# ['could', "n't", 'believe', 'when', 'he', 'called', 'me']
# ['soon', 'as', 'a', 'nigga', 'hit', 'the', 'stage', ',', 'they', 'gon', "'", '...']
# ['it', 'ai', "n't", 'a', 'secret', ',', 'baby', ',', 'everybody', 'saw', 'us']
# ['how', 'you', 'let', 'the', 'kid', 'fightin', "'"]
# ['i', 'was', 'runnin', "'", 'through', 'the', '6', 'with', 'my', 'woes']
# ['cry', 'for', 'me', ',', 'cry', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'die', 'for', 'me']
# ['looking', 'for', 'revenge']
# ['she', 'was', 'playin', "'", 'with', 'me', 'then', 'but', 'she', 'waitin', "'", 'now', '(', '21', ',', '21', ')']
# ['cry', 'for', 'me', ',', 'cry', 'for', 'me', ',', 'you', 'said', 'you', "'d", 'cry', 'for', 'me']
# ['make', 'me', 'call', 'my', 'bro', '(', '21', ',', 'uh', ')']
# ['say', 'my', 'name', ',', 'say', 'my', 'name']
# ['get', 'what', 'i', 'can', 'out', 'the', 'country']
# ['i', 'had', 'to', 'derrick', 'rose', 'the', 'knee', 'up', 'before', 'i', 'got', 'the', 're', '-', 'up']
# ['nobody', 'else', "'s", ',', 'yeah', ',', 'this', 'shit', 'belong', 'to', 'nobody', ',', 'it', "'s", 'yours']
# ['i', 'just', 'might', 'bring', 'in', 'some', 'girls', 'from', 'miami']
# ['i', 'been', 'at', 'the', 'house', 'takin', "'", 'no', 'calls']
# ['so', ',', 'you', 'do', "n't", 'rap', 'what', 'you', 'did', ',', 'you', 'just', 'rap', 'what', 'you', 'knew']
# []
# ['it', "'s", 'like', 'every', 'time', 'i', 'touch', 'it', 'i', 'could', 'never', 'do', 'no', 'wrong']
# ['i', 'just', 'do', "n't", 'understand', 'it']
# ['industry', 'people', '....', 'regular', 'people', '...']
# ['cashing', 'checks', 'and', 'i', '’m', 'bigging', 'up', 'my', 'chest']
# ['she', 'ai', "n't", 'fuckin', "'", 'with', 'you', 'niggas']
# ['how', 'much', 'i', 'make', 'off', 'the', 'deal', ',', 'how', 'the', 'fuck', 'should', 'i', 'know', '?']
# ['next', 'time', 'we', 'talk', ',', 'i', 'do', "n't", 'wanna', 'just', 'talk', ',', 'i', 'wanna', 'trust']
# ['rock', 'me', 'real', 'slowly']
# ['i', '’m', 'out', 'here', '…']
# ['i', 'do', "n't", 'know', 'who', 'you', "'re", 'referring', 'to']
# ['steady', "doin'", 'double', 'shifts']
# ['niggas', 'would', "n't", 'make', 'it', 'on', 'this', 'side']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-cc8f2272865e> in <module>
#      37     print(example.text)
#      38
# ---> 39 vectors=Vectors(name='glove.6B.100d.txt')
#      40 TEXT.build_vocab(training_data, vectors=vectors, max_size=10000, min_freq=1)
#      41 #train_X, train_y = seq[:, :-1],
#
# NameError: name 'Vectors' is not defined

# %%
pad_encoded_data = [pad_tensor(x, length=10) for x in encoded_data]
print(stack_and_pad_tensors(pad_encoded_data))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-29-c84c0e0d96f9> in <module>
# ----> 1 pad_encoded_data = [pad_tensor(x, length=10) for x in encoded_data]
#       2 print(stack_and_pad_tensors(pad_encoded_data))
#
# <ipython-input-29-c84c0e0d96f9> in <listcomp>(.0)
# ----> 1 pad_encoded_data = [pad_tensor(x, length=10) for x in encoded_data]
#       2 print(stack_and_pad_tensors(pad_encoded_data))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torchnlp/encoders/text/text_encoder.py in pad_tensor(tensor, length, padding_index)
#      19     """
#      20     n_padding = length - tensor.shape[0]
# ---> 21     assert n_padding >= 0
#      22     if n_padding == 0:
#      23         return tensor
#
# AssertionError:

# %%
raw_data_Drake = {'Drake_data': [line for line in lyrics_data_Drake]}
#raw_data_Childish = {'Childish_data': [line for line in lyrics_data]}
#raw_data_Kanye = {'Kanye_data': [line for line in lyrics_data]}

#convert data to dataframe
df = pd.DataFrame(raw_data_Drake, columns = ['Drake_data'])

#shuffle dataset... is this necessary this early?
shuffle_dataframe = df.sample(frac=1)

#Split data : define size of training dataset
train_size = int(0.7*len(df))

#split into training and test set
train_set = shuffle_dataframe[:train_size]
test_set = shuffle_dataframe[train_size:]

#output for torchtext (needs a tabular dataset)
train_set.to_json('train.json', orient = 'records', lines =True)
test_set.to_json('test.json', orient = 'records', lines =True)

train_set.to_csv('train.csv', index=False)
test_set.to_csv('test.csv', index=False)

print(train_set), print(test_set)
# Out:
#                                              Drake_data
# 2724               Yeah, met her once and I got through
# 3749  I've had mine, you've had yours, we both know....
# 3614                     And you know what's on my mind
# 2345     You be like "who's this?" I be like "me, girl"
# 724   I needed to hear that shit, I hate when you're...
# ...                                                 ...
# 2835                    They know, they know, they know
# 1597        Yeah, they don't really be the same offline
# 277                    He put me on to the finer things
# 3871   Just to off these records, nigga that's a record
# 32            I only love my bed and my mama, I'm sorry
#
# [2971 rows x 1 columns]
#                                              Drake_data
# 1171               I got enemies,  got a lot of enemies
# 3443                         Make me call my bro, don't
# 943   My high school reunion might be worth an appea...
# 3106                So worried that I won't be accepted
# 3256                        I'll be here, just swanging
# ...                                                 ...
# 3999  Last chance I get to make sure that you take i...
# 3776                        You wanna grip a Benz wheel
# 4083                Let's just not even discuss it, man
# 3028                                               Whoa
# 1739            They’re trying to take you away from me
#
# [1274 rows x 1 columns]
# (None, None)

# %% [markdown]
# ## SimpleRNN Model

# %%
#RNN Model
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.i2h = nn.Linear(input_size + hidden_size, hideen_size)
        self.i2o = nn.Linear(input_size + hidden_size, output_size)
        #we takee second dimension (count starts at 0) our shape is [1,512] - why 512?
        self.softmax = nn.LogSoftmax(dim=1)
    

    def forward (self, input_tensor, hidden_tensor):
        #curr hid state is a combo of prev hid state and curr input
        combined = torch.cat((input_tensor, hidden_tensor), 1)
        hidden = self.i2h(combined)
        output = self.i2o(combined)
        output = self.softmax(output)
  
    return output, hidden 

"""  
model = NN(100, 10)
#figure out what size we want to return
x = torch.randn(10, 20)
print(model(x).shape)
"""

#run on device (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


#hyperparameters (input size of vector, sequence, num layers, hidden layers, hidden size)
# input size and classes have placeholder for now
input_size = 512
output_size = 1
hidden_size = 1
learning_rate = 0.001
batch_size = 10
num_epochs = 50

#load data for training
#check if train_data is in correct format
train_loader = DataLoader(dataset=train_set, batch_size=batch_size, shuffle = True)
test_loader = DataLoader(dataset=test_set, batch_size=batch_size, shuffle = True)

#do we need to initialize network? cpu/cuda?

#optimizer and loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = learning_rate)

#Training Step
for epoch in range(num_epochs, category_tensor):
    for batch_index ,(data, targets) in enumerate(train_loader):
        data = data.to(device=device)
        targets = targets.to(device=device)

        data = data.shape[1]
        #we have one dimension (one column in data), but we have a dictionary inside each colm.

        #forward part of NN
        scores = mode(data)
        #loss = criterion(scores, targets)
        loss = criterion(output, category_tensor)

        #backward, we don't go bckwd so we set gradient to 0 for every batch, so we don't store back props
        optimizer.zero_grad()
        loss.backward()

        #gradient descent, update weights based on loss.backward
        optimizer.step()

        return otput, loss.item()

#training loop
current_loss = 0
all_losses = []
plot_steps, print_steps = 1000, 5000
num_iter = 100000
for i in range(num_iter):
#...
# Out:
#   File "<ipython-input-3-83d10761ee6a>", line 81
#     #...
#         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## LSTM Model

# %%
class LSTM(nn.Module):
    
    ''' Initialize the network variables '''
    def __init__(self, num_hidden, num_layers, embed_size, drop_prob, lr):
        # call super() on the class
        super().__init__()
        
        # store the constructor variables
        self.drop_prob = drop_prob
        self.num_layers = num_layers
        self.num_hidden = num_hidden
        self.lr = lr
        
        # define the embedded layer
        self.embedded = nn.Embedding(vocab_size, embed_size)

        # define the LSTM
        self.lstm = nn.LSTM(embed_size, num_hidden, num_layers, dropout = drop_prob, batch_first = True)
        
        # define a dropout layer
        self.dropout = nn.Dropout(drop_prob)
        
        # define the fully-connected layer
        self.fc = nn.Linear(num_hidden, vocab_size)      
    
    ''' Forward propogate through the network '''
    def forward(self, x, hidden):
        
        ## pass input through embedding layer
        embedded = self.embedded(x)     
        
        # Obtain the outputs and hidden layer from the LSTM layer
        lstm_output, hidden = self.lstm(embedded, hidden)
        
        # pass through a dropout layer and reshape
        dropout_out = self.dropout(lstm_output).reshape(-1, self.num_hidden) 

        ## put "out" through the fully-connected layer
        out = self.fc(dropout_out)

        # return the final output and the hidden state
        return out, hidden
    
    ''' Initialize the hidden state of the network '''
    def init_hidden(self, batch_size):
        
        # Create a weight torch using the parameters of the model
        weight = next(self.parameters()).data

        # initialize the hidden layer using the weight torch
        hidden = (weight.new(self.num_layers, batch_size, self.num_hidden).zero_(),
                  weight.new(self.num_layers, batch_size, self.num_hidden).zero_())
        
        # return the hidden layer
        return hidden
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4a976c973a78> in <module>
# ----> 1 class LSTM(nn.Module):
#       2
#       3     ''' Initialize the network variables '''
#       4     def __init__(self, num_hidden, num_layers, embed_size, drop_prob, lr):
#       5         # call super() on the class
#
# NameError: name 'nn' is not defined

# %%
# create the LSTM model
model = LSTM(num_hidden, num_layers, embed_size, drop_prob, lr)

# selecting an optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = lr)

# selecting a loss function
loss_func = nn.CrossEntropyLoss()

# overview of the model
model.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1f0a20c7364a> in <module>
#       1 # create the LSTM model
# ----> 2 model = LSTM(num_hidden, num_layers, embed_size, drop_prob, lr)
#       3
#       4 # selecting an optimizer
#       5 optimizer = torch.optim.Adam(model.parameters(), lr = lr)
#
# NameError: name 'LSTM' is not defined

# %%
def get_next_batch(x, y, batch_size):
    
    # iterate until the end of x
    for itr in range(batch_size, x.shape[0], batch_size):
        
        # obtain the indexed x and y values
        batch_x = x[itr - batch_size:itr, :]
        batch_y = y[itr - batch_size:itr, :]
        
        # yield these values
        yield batch_x, batch_y

# %%
for epoch in range(num_epochs):

    # initialize hidden state
    hidden_layer = model.init_hidden(batch_size)
        
    for x, y in get_next_batch(x_idx, y_idx, batch_size):
            
        # convert numpy arrays to PyTorch arrays
        inputs = torch.from_numpy(x).type(torch.LongTensor)
        act = torch.from_numpy(y).type(torch.LongTensor)

        # reformat the hidden layer
        hidden_layer = tuple([layer.data for layer in hidden_layer])

        # obtain the zero-accumulated gradients from the model
        model.zero_grad()
            
        # get the output from the model
        output, hidden = model(inputs, hidden_layer)
            
        # calculate the loss from this prediction
        loss = loss_func(output, act.view(-1))

        # back-propagate to update the model
        loss.backward()

        # prevent exploding gradient problem
        nn.utils.clip_grad_norm_(model.parameters(), 1)

        # update weigths using the optimizer
        optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5c944ac68071> in <module>
# ----> 1 for epoch in range(num_epochs):
#       2
#       3     # initialize hidden state
#       4     hidden_layer = model.init_hidden(batch_size)
#       5
#
# NameError: name 'num_epochs' is not defined

# %% [markdown]
# ## Generating Lyrics

# %%
def generate_rap(model, artists_bars, length_of_bar=10, length_of_rap=20, min_score_threshold=-0.2, max_score_threshold=0.2, tries=5):
    artists_avg_readability = calc_readability(artists_bars)
    artists_avg_rhyme_idx = calc_rhyme_density(artists_bars)
    fire_rap = []
    cur_tries = 0
    candidate_bars = []

    while len(fire_rap) < length_of_rap:
        seed_phrase = markov_model.make_sentence(tries=500).split(" ")
        seed_phrase = " ".join(seed_phrase[:3])
        cur_tries += 1
        bar = generate_bar(seed_phrase, model, rand.randrange(4, length_of_bar))
        bar_score = score_bar(bar, artist_lyrics, artists_avg_readability, artists_avg_rhyme_idx) 
        candidate_bars.append((bar_score, bar))

    if bar_score <= max_score_threshold and bar_score >= min_score_threshold:
        fire_rap.append(bar)
        cur_tries = 0
        print("Generated Bar: ", len(fire_rap))

    if cur_tries >= tries:
        lowest_score = np.Infinity
        best_bar = ""
        for bar in candidate_bars:
            if bar[0] < lowest_score:
                best_bar = bar[1]
                candidate_bars = []
      
    print("Generated Bar: ", len(fire_rap))
    fire_rap.append(best_bar)
    cur_tries = 0
      
    print("Generated rap with avg rhyme density: ", calc_rhyme_density(fire_rap), "and avg readability of: ", calc_readability(fire_rap))
    return fire_rap

# %%
def generate_bar(seed_phrase, model, length_of_bar):
    for i in range(length_of_bar):
        seed_tokens = pad_sequences(tokenizer.texts_to_sequences([seed_phrase]), maxlen=29)
        output_p = model.predict(seed_tokens)
        output_word = np.argmax(output_p, axis=1)[0]-1
        seed_phrase += " " + str(list(tokenizer.word_index.items())[output_word][0])
    return seed_phrase

# %%
def compare_bars(input_bar, artists_bars):
  
    # Convert sentences to matrix of token counts
    avg_distance = 0
    total_counted = 0
    for bar in artists_bars:
        v = CountVectorizer()
        # Vectorize the sentences
        word_vector = v.fit_transform([input_bar, bar])
    # Compute the cosine distance between the sentence vectors
        cos_distance = 1-pdist(word_vector.toarray(), 'cosine')[0]
    if not math.isnan(cos_dist):
        avg_distance += 1-pdist(word_vector.toarray(), 'cosine')[0]
        total_counted += 1
    return avg_distance/total_counted

# %%
def calc_rhyme_density(bars):
    total_syllables = 0
    rhymed_syllables = 0
    for bar in bars:
        for word in bar.split():
        p = pronouncing.phones_for_word(word)
        if len(p) == 0:
            break
        syllables = pronouncing.syllable_count(p[0])
        total_syllables += syllables
        has_rhyme = False
        for rhyme in pronouncing.rhymes(word):
        if has_rhyme:
            break
        for idx, r_bar in enumerate(bars):
            if idx > 4:
                break
            if rhyme in r_bar:
                rhymed_syllables += syllables
                has_rhyme = True
                break
    return rhymed_syllables/total_syllables

# %%
def calc_readability(input_bars):
    avg_readability = 0
    for bar in input_bars:
        avg_readability += textstat.automated_readability_index(bar)
    return avg_readability / len(input_bars)

# %%
def score_bar(input_bar, artists_bars, artists_avg_readability, artists_avg_rhyme_idx):
    gen_readability = textstat.automated_readability_index(input_bar)
    gen_rhyme_idx = calc_rhyme_density(input_bar)
    comp_bars = compare_bars(input_bar, artists_bars)

    # Scores based off readability, rhyme index, and originality. The lower the score the better.
    bar_score = (artists_avg_readability - gen_readability) + (artists_avg_rhyme_idx - gen_rhyme_idx) + comp_bars
    return bar_score

# %%
rnn = generate_rap(rnn_model, artist_lyrics, length_of_bar = 8, tries=100)

print("Rap Generated with SimpleRNN:")
for line in rnn:
    print(line)
print()

lstm = generate_rap(lstm_model, artist_lyrics, length_of_bar = 8, tries=100)

print("Rap Generated with LSTM:")
for line in lstm:
    print(line)
print()
